# %%
import os, sys
os.chdir('/home/seigyo/Documents/pytorch/brain_decoder')
sys.path.append(os.pardir)
import numpy as np
from numpy.random import RandomState
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch import optim
import mne
from mne.io import concatenate_raws
from mymodule.utils import data_loader, evaluator
from mymodule.layers import LSTM, Residual_block, Res_net, Wavelet_cnn, NlayersSeqConvLSTM
from mymodule.trainer import Trainer
from mymodule.optim import Eve, YFOptimizer
from sklearn.utils import shuffle
from tensorboardX import SummaryWriter
from load_data import get_data, get_data_multi, get_crops, get_crops_multi
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

epochs = 100
batch_size = 10
cv_splits = 5
torch.manual_seed(1214)
torch.cuda.manual_seed_all(1214)
num_of_subjects = 99



class Conv_lstm(nn.Module):
  def __init__(self):
    super(Conv_lstm, self).__init__()
    self.conv_time = nn.Conv2d(1, 40, (25, 1))
    self.batchnorm1 = nn.BatchNorm2d(40)
    self.conv_spat = nn.Conv2d(40, 40, (1, 64), bias=False)
    self.batchnorm2 = nn.BatchNorm2d(40)
    self.pool = nn.AvgPool2d(kernel_size=(75, 1), stride=(15, 1))
    self.dropout = nn.Dropout2d(p=0.5)
    self.lstm = LSTM(40, 10, batch_size, bidirectional=True, gpu=True, return_seq=False)
    self.dropout_linear = nn.Dropout(p=0.5)
    self.classifier = nn.Linear(20, 2)

  def forward(self, x):
    h = self.conv_time(x)
#     h = self.batchnorm1(h)
    h = self.conv_spat(h)
    h = self.batchnorm2(h)
    h = self.pool(h)
    h = self.dropout(h)
    h = h.squeeze().transpose(1, 2)
    h = self.lstm(h)
    h = self.dropout_linear(h)
    h = self.classifier(h)
    return h

# criterion = torch.nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

def cv_train(model_class, criterion_class, optimizer_class, X, y,
             epoch=100, num_of_cv=10, batch_size=16):
    kf = KFold(n_splits=num_of_cv, shuffle=True)
    accuracy = []
    for train_idx, val_idx in kf.split(X=X, y=y):
        train_x, val_x = X[train_idx], X[val_idx]
        train_y, val_y = y[train_idx], y[val_idx]
        train_loader = data_loader(train_x, train_y, batch_size=batch_size,
                           shuffle=True, gpu=False)
        val_loader = data_loader(val_x, val_y, batch_size=batch_size)
        writer = SummaryWriter()
        model = model_class().cuda()
        criterion = criterion_class()
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        trainer = Trainer(model, criterion, optimizer,
                  train_loader, val_loader,
                  val_num=1, early_stopping=2,
                  writer=writer, gpu=True)
        trainer.run(epochs=epoch)
        accuracy.append(trainer.val_best_acc)
    return accuracy


all_accs_list = []
all_mean_list = []
all_var_list = []

for idx in range(num_of_subjects):
    X, y = get_data(id=idx+1, event_code=[6,10,14], filter=[0.5, 30], t=[0., 4])
    X = X.reshape(X.shape[0], 1, X.shape[1], X.shape[2]).transpose(0,1,3,2)

#     model = Conv_lstm()
#     model.cuda()

    acc = cv_train(Conv_lstm, torch.nn.CrossEntropyLoss,
                   torch.optim.Adam, X, y, epoch=epochs,
                   num_of_cv=cv_splits, batch_size=batch_size)

    mean = np.mean(acc)
    var = np.var(acc)
    print('subject{}   mean_acc:{}, var_acc:{}'.format(idx+1, mean, var))

    all_accs_list.append(acc)
    all_mean_list.append(mean)
    all_var_list.append(var)

all_mean = np.mean(all_accs_list)
all_var = np.var(all_accs_list)

print('all subjects  mean_acc:{}, var_acc:{}'.format(all_mean, all_var))
# Out:
# Removing orphaned offset at the beginning of the file.
# 89 events found
# Events id: [1 2 3]
# 45 matching events found
# Not setting metadata
# Loading data for 45 events and 641 original time points ...
# 0 bad epochs dropped
# ----------start training----------
# epoch:1, tr_loss:0.5671, tr_acc:0.4722,   val_loss:0.3276, val_acc:0.6667
# epoch:2, tr_loss:0.5657, tr_acc:0.4444,   val_loss:0.3300, val_acc:0.6667
# epoch:3, tr_loss:0.5538, tr_acc:0.5000,   val_loss:0.3298, val_acc:0.6667
# epoch:4, tr_loss:0.5447, tr_acc:0.4167,   val_loss:0.3303, val_acc:0.7778
# epoch:5, tr_loss:0.5506, tr_acc:0.5278,   val_loss:0.3304, val_acc:0.6667
# epoch:6, tr_loss:0.5308, tr_acc:0.5833,   val_loss:0.3318, val_acc:0.6667
# epoch:7, tr_loss:0.5428, tr_acc:0.5000,   val_loss:0.3337, val_acc:0.6667
# epoch:8, tr_loss:0.5163, tr_acc:0.6667,   val_loss:0.3357, val_acc:0.6667
# epoch:9, tr_loss:0.5292, tr_acc:0.6944,   val_loss:0.3361, val_acc:0.6667
# epoch:10, tr_loss:0.5313, tr_acc:0.5556,   val_loss:0.3362, val_acc:0.6667
# epoch:11, tr_loss:0.4880, tr_acc:0.7222,   val_loss:0.3361, val_acc:0.5556
# epoch:12, tr_loss:0.5039, tr_acc:0.7500,   val_loss:0.3355, val_acc:0.4444
# epoch:13, tr_loss:0.5076, tr_acc:0.6944,   val_loss:0.3358, val_acc:0.4444
# epoch:14, tr_loss:0.4855, tr_acc:0.8333,   val_loss:0.3374, val_acc:0.4444
# epoch:15, tr_loss:0.4495, tr_acc:0.8056,   val_loss:0.3424, val_acc:0.4444
# epoch:16, tr_loss:0.4909, tr_acc:0.6667,   val_loss:0.3468, val_acc:0.3333
# epoch:17, tr_loss:0.4910, tr_acc:0.7500,   val_loss:0.3535, val_acc:0.3333
# epoch:18, tr_loss:0.4603, tr_acc:0.7500,   val_loss:0.3595, val_acc:0.3333
# epoch:19, tr_loss:0.4889, tr_acc:0.6944,   val_loss:0.3667, val_acc:0.3333
# epoch:20, tr_loss:0.4585, tr_acc:0.7500,   val_loss:0.3692, val_acc:0.4444
# epoch:21, tr_loss:0.4402, tr_acc:0.8889,   val_loss:0.3720, val_acc:0.4444
# epoch:22, tr_loss:0.4316, tr_acc:0.8056,   val_loss:0.3785, val_acc:0.4444
# epoch:23, tr_loss:0.4204, tr_acc:0.8333,   val_loss:0.3868, val_acc:0.4444
# epoch:24, tr_loss:0.4184, tr_acc:0.8333,   val_loss:0.3929, val_acc:0.4444
# epoch:25, tr_loss:0.3828, tr_acc:0.9444,   val_loss:0.3982, val_acc:0.4444
# epoch:26, tr_loss:0.4330, tr_acc:0.8056,   val_loss:0.4004, val_acc:0.5556
# epoch:27, tr_loss:0.3670, tr_acc:0.8611,   val_loss:0.4125, val_acc:0.4444
# epoch:28, tr_loss:0.4034, tr_acc:0.8611,   val_loss:0.4263, val_acc:0.4444
# epoch:29, tr_loss:0.3743, tr_acc:0.8611,   val_loss:0.4264, val_acc:0.4444
# epoch:30, tr_loss:0.3655, tr_acc:0.8611,   val_loss:0.4260, val_acc:0.5556
# epoch:31, tr_loss:0.3863, tr_acc:0.8889,   val_loss:0.4358, val_acc:0.5556
# epoch:32, tr_loss:0.3484, tr_acc:0.8611,   val_loss:0.4463, val_acc:0.4444
# epoch:33, tr_loss:0.3536, tr_acc:0.7778,   val_loss:0.4547, val_acc:0.5556
# epoch:34, tr_loss:0.3939, tr_acc:0.8056,   val_loss:0.4527, val_acc:0.4444
# epoch:35, tr_loss:0.3458, tr_acc:0.8889,   val_loss:0.4588, val_acc:0.5556
# epoch:36, tr_loss:0.3702, tr_acc:0.8611,   val_loss:0.4637, val_acc:0.5556
# epoch:37, tr_loss:0.3079, tr_acc:0.8889,   val_loss:0.4712, val_acc:0.5556
# epoch:38, tr_loss:0.3573, tr_acc:0.8611,   val_loss:0.4765, val_acc:0.5556
# epoch:39, tr_loss:0.2917, tr_acc:0.8889,   val_loss:0.4796, val_acc:0.5556
# epoch:40, tr_loss:0.2886, tr_acc:0.9444,   val_loss:0.4829, val_acc:0.5556
# epoch:41, tr_loss:0.2913, tr_acc:0.9444,   val_loss:0.4751, val_acc:0.6667
# epoch:42, tr_loss:0.2675, tr_acc:0.8889,   val_loss:0.4787, val_acc:0.5556
# epoch:43, tr_loss:0.2567, tr_acc:0.8889,   val_loss:0.4807, val_acc:0.5556
# epoch:44, tr_loss:0.2644, tr_acc:0.9444,   val_loss:0.4854, val_acc:0.5556
# epoch:45, tr_loss:0.2710, tr_acc:0.9444,   val_loss:0.5098, val_acc:0.5556
# epoch:46, tr_loss:0.2598, tr_acc:0.9167,   val_loss:0.4993, val_acc:0.5556
# epoch:47, tr_loss:0.2075, tr_acc:0.9167,   val_loss:0.5053, val_acc:0.5556
# epoch:48, tr_loss:0.2197, tr_acc:0.9444,   val_loss:0.5171, val_acc:0.5556
# epoch:49, tr_loss:0.2700, tr_acc:0.9167,   val_loss:0.5439, val_acc:0.5556
# epoch:50, tr_loss:0.1938, tr_acc:0.9444,   val_loss:0.5431, val_acc:0.5556
# epoch:51, tr_loss:0.2314, tr_acc:0.9444,   val_loss:0.5408, val_acc:0.5556
# epoch:52, tr_loss:0.3044, tr_acc:0.8889,   val_loss:0.5414, val_acc:0.5556
# epoch:53, tr_loss:0.2129, tr_acc:0.9722,   val_loss:0.5140, val_acc:0.6667
# epoch:54, tr_loss:0.1952, tr_acc:0.9444,   val_loss:0.5174, val_acc:0.5556
# epoch:55, tr_loss:0.2071, tr_acc:0.9167,   val_loss:0.5383, val_acc:0.5556
# epoch:56, tr_loss:0.2522, tr_acc:0.9167,   val_loss:0.5470, val_acc:0.5556
# epoch:57, tr_loss:0.2035, tr_acc:0.9444,   val_loss:0.5644, val_acc:0.4444
# epoch:58, tr_loss:0.2198, tr_acc:0.9444,   val_loss:0.5672, val_acc:0.4444
# epoch:59, tr_loss:0.2631, tr_acc:0.9167,   val_loss:0.5695, val_acc:0.5556
# epoch:60, tr_loss:0.1892, tr_acc:0.9444,   val_loss:0.5385, val_acc:0.5556
# epoch:61, tr_loss:0.1822, tr_acc:0.9444,   val_loss:0.5470, val_acc:0.5556
# epoch:62, tr_loss:0.1977, tr_acc:0.9444,   val_loss:0.5651, val_acc:0.5556
# epoch:63, tr_loss:0.2099, tr_acc:0.9722,   val_loss:0.6059, val_acc:0.4444
# epoch:64, tr_loss:0.1933, tr_acc:0.9444,   val_loss:0.6821, val_acc:0.4444
# epoch:65, tr_loss:0.1554, tr_acc:0.9444,   val_loss:0.5913, val_acc:0.4444
# epoch:66, tr_loss:0.1335, tr_acc:0.9722,   val_loss:0.5683, val_acc:0.5556
# epoch:67, tr_loss:0.1400, tr_acc:0.9722,   val_loss:0.5795, val_acc:0.5556
# epoch:68, tr_loss:0.1635, tr_acc:0.9722,   val_loss:0.5822, val_acc:0.5556
# epoch:69, tr_loss:0.2172, tr_acc:0.9167,   val_loss:0.5568, val_acc:0.6667
# epoch:70, tr_loss:0.1419, tr_acc:0.9722,   val_loss:0.5709, val_acc:0.6667
# epoch:71, tr_loss:0.1234, tr_acc:0.9722,   val_loss:0.6070, val_acc:0.5556
# epoch:72, tr_loss:0.1095, tr_acc:0.9722,   val_loss:0.6335, val_acc:0.5556
# epoch:73, tr_loss:0.1541, tr_acc:0.9167,   val_loss:0.5985, val_acc:0.5556
# epoch:74, tr_loss:0.1548, tr_acc:0.9722,   val_loss:0.5955, val_acc:0.6667
# epoch:75, tr_loss:0.1244, tr_acc:0.9722,   val_loss:0.5932, val_acc:0.6667
# epoch:76, tr_loss:0.1078, tr_acc:0.9444,   val_loss:0.5797, val_acc:0.6667
# epoch:77, tr_loss:0.1244, tr_acc:0.9722,   val_loss:0.5795, val_acc:0.6667
# epoch:78, tr_loss:0.1420, tr_acc:0.9722,   val_loss:0.5870, val_acc:0.6667
# epoch:79, tr_loss:0.1206, tr_acc:0.9722,   val_loss:0.5871, val_acc:0.6667
# epoch:80, tr_loss:0.1027, tr_acc:0.9722,   val_loss:0.5834, val_acc:0.6667
# epoch:81, tr_loss:0.0960, tr_acc:0.9722,   val_loss:0.5982, val_acc:0.6667
# epoch:82, tr_loss:0.1632, tr_acc:0.9444,   val_loss:0.6324, val_acc:0.5556
# epoch:83, tr_loss:0.1387, tr_acc:0.9722,   val_loss:0.6355, val_acc:0.5556
# epoch:84, tr_loss:0.1282, tr_acc:0.9444,   val_loss:0.6530, val_acc:0.5556
# epoch:85, tr_loss:0.1075, tr_acc:0.9722,   val_loss:0.6595, val_acc:0.5556
# epoch:86, tr_loss:0.1181, tr_acc:0.9444,   val_loss:0.6282, val_acc:0.6667
# epoch:87, tr_loss:0.1248, tr_acc:1.0000,   val_loss:0.6321, val_acc:0.6667
# epoch:88, tr_loss:0.1083, tr_acc:0.9722,   val_loss:0.6389, val_acc:0.6667
# epoch:89, tr_loss:0.1271, tr_acc:0.9722,   val_loss:0.6263, val_acc:0.6667
# epoch:90, tr_loss:0.1045, tr_acc:0.9722,   val_loss:0.6541, val_acc:0.6667
# epoch:91, tr_loss:0.0906, tr_acc:1.0000,   val_loss:0.6821, val_acc:0.5556
# epoch:92, tr_loss:0.1207, tr_acc:0.9167,   val_loss:0.6290, val_acc:0.6667
# epoch:93, tr_loss:0.0901, tr_acc:0.9722,   val_loss:0.6256, val_acc:0.6667
# epoch:94, tr_loss:0.1231, tr_acc:0.9722,   val_loss:0.6269, val_acc:0.6667
# epoch:95, tr_loss:0.0563, tr_acc:1.0000,   val_loss:0.6236, val_acc:0.6667
# epoch:96, tr_loss:0.1078, tr_acc:0.9444,   val_loss:0.6308, val_acc:0.6667
# epoch:97, tr_loss:0.1000, tr_acc:0.9722,   val_loss:0.6427, val_acc:0.6667
# epoch:98, tr_loss:0.0787, tr_acc:1.0000,   val_loss:0.6621, val_acc:0.6667
# epoch:99, tr_loss:0.0980, tr_acc:0.9722,   val_loss:0.7150, val_acc:0.5556
# epoch:100, tr_loss:0.1024, tr_acc:0.9444,   val_loss:0.7012, val_acc:0.6667
# ----------finish training---------
# training_best_acc:1.0, val_best_acc:0.7777777777777778
# ----------start training----------
# epoch:1, tr_loss:0.5553, tr_acc:0.5278,   val_loss:0.3303, val_acc:0.6667
# epoch:2, tr_loss:0.5571, tr_acc:0.5278,   val_loss:0.3282, val_acc:0.6667
# epoch:3, tr_loss:0.5285, tr_acc:0.5556,   val_loss:0.3293, val_acc:0.6667
# epoch:4, tr_loss:0.5342, tr_acc:0.5278,   val_loss:0.3294, val_acc:0.6667
# epoch:5, tr_loss:0.5110, tr_acc:0.5556,   val_loss:0.3292, val_acc:0.6667
# epoch:6, tr_loss:0.5177, tr_acc:0.5833,   val_loss:0.3303, val_acc:0.5556
# epoch:7, tr_loss:0.5106, tr_acc:0.6389,   val_loss:0.3315, val_acc:0.5556
# epoch:8, tr_loss:0.5277, tr_acc:0.5833,   val_loss:0.3322, val_acc:0.5556
# epoch:9, tr_loss:0.5469, tr_acc:0.6667,   val_loss:0.3331, val_acc:0.5556
# epoch:10, tr_loss:0.5114, tr_acc:0.6944,   val_loss:0.3340, val_acc:0.5556
# epoch:11, tr_loss:0.5176, tr_acc:0.6111,   val_loss:0.3341, val_acc:0.5556
# epoch:12, tr_loss:0.5119, tr_acc:0.6944,   val_loss:0.3350, val_acc:0.5556
# epoch:13, tr_loss:0.4965, tr_acc:0.6389,   val_loss:0.3362, val_acc:0.5556
# epoch:14, tr_loss:0.4890, tr_acc:0.6667,   val_loss:0.3372, val_acc:0.5556
# epoch:15, tr_loss:0.5105, tr_acc:0.6389,   val_loss:0.3381, val_acc:0.6667
# epoch:16, tr_loss:0.5057, tr_acc:0.6667,   val_loss:0.3396, val_acc:0.6667
# epoch:17, tr_loss:0.4659, tr_acc:0.7500,   val_loss:0.3417, val_acc:0.6667
# epoch:18, tr_loss:0.5034, tr_acc:0.7222,   val_loss:0.3435, val_acc:0.6667
# epoch:19, tr_loss:0.4633, tr_acc:0.7500,   val_loss:0.3454, val_acc:0.6667
# epoch:20, tr_loss:0.4565, tr_acc:0.7778,   val_loss:0.3480, val_acc:0.5556
# epoch:21, tr_loss:0.4694, tr_acc:0.7500,   val_loss:0.3497, val_acc:0.5556
# epoch:22, tr_loss:0.4631, tr_acc:0.8333,   val_loss:0.3538, val_acc:0.4444
# epoch:23, tr_loss:0.4555, tr_acc:0.7500,   val_loss:0.3553, val_acc:0.4444
# epoch:24, tr_loss:0.4617, tr_acc:0.8333,   val_loss:0.3560, val_acc:0.4444
# epoch:25, tr_loss:0.4253, tr_acc:0.8889,   val_loss:0.3593, val_acc:0.4444
# epoch:26, tr_loss:0.3978, tr_acc:0.8889,   val_loss:0.3610, val_acc:0.4444
# epoch:27, tr_loss:0.4278, tr_acc:0.7778,   val_loss:0.3647, val_acc:0.4444
# epoch:28, tr_loss:0.4103, tr_acc:0.8056,   val_loss:0.3692, val_acc:0.4444
# epoch:29, tr_loss:0.3982, tr_acc:0.8889,   val_loss:0.3728, val_acc:0.4444
# epoch:30, tr_loss:0.4032, tr_acc:0.8056,   val_loss:0.3717, val_acc:0.5556
# epoch:31, tr_loss:0.4191, tr_acc:0.7778,   val_loss:0.3750, val_acc:0.5556
# epoch:32, tr_loss:0.3948, tr_acc:0.8611,   val_loss:0.3830, val_acc:0.5556
# epoch:33, tr_loss:0.3611, tr_acc:0.8611,   val_loss:0.3914, val_acc:0.5556
# epoch:34, tr_loss:0.3421, tr_acc:0.9167,   val_loss:0.4079, val_acc:0.5556
# epoch:35, tr_loss:0.3498, tr_acc:0.8056,   val_loss:0.4136, val_acc:0.5556
# epoch:36, tr_loss:0.3297, tr_acc:0.9444,   val_loss:0.4094, val_acc:0.4444
# epoch:37, tr_loss:0.3511, tr_acc:0.8333,   val_loss:0.4032, val_acc:0.5556
# epoch:38, tr_loss:0.3561, tr_acc:0.8611,   val_loss:0.4087, val_acc:0.5556
# epoch:39, tr_loss:0.3166, tr_acc:0.8611,   val_loss:0.4378, val_acc:0.4444
# epoch:40, tr_loss:0.3447, tr_acc:0.8056,   val_loss:0.4487, val_acc:0.4444
# epoch:41, tr_loss:0.2978, tr_acc:0.8333,   val_loss:0.4564, val_acc:0.5556
# epoch:42, tr_loss:0.3848, tr_acc:0.9167,   val_loss:0.4554, val_acc:0.5556
# epoch:43, tr_loss:0.3225, tr_acc:0.8611,   val_loss:0.4577, val_acc:0.4444
# epoch:44, tr_loss:0.3212, tr_acc:0.9167,   val_loss:0.4764, val_acc:0.4444
# epoch:45, tr_loss:0.3135, tr_acc:0.8611,   val_loss:0.4979, val_acc:0.4444
# epoch:46, tr_loss:0.3020, tr_acc:0.8889,   val_loss:0.5155, val_acc:0.4444
# epoch:47, tr_loss:0.2827, tr_acc:0.9444,   val_loss:0.5092, val_acc:0.4444
# epoch:48, tr_loss:0.2698, tr_acc:0.9167,   val_loss:0.5000, val_acc:0.4444
# epoch:49, tr_loss:0.2701, tr_acc:0.9167,   val_loss:0.4853, val_acc:0.5556
# epoch:50, tr_loss:0.2733, tr_acc:0.9167,   val_loss:0.5002, val_acc:0.4444
# epoch:51, tr_loss:0.2410, tr_acc:0.9722,   val_loss:0.5121, val_acc:0.4444
# epoch:52, tr_loss:0.2226, tr_acc:0.9444,   val_loss:0.5077, val_acc:0.4444
# epoch:53, tr_loss:0.1875, tr_acc:0.9722,   val_loss:0.4998, val_acc:0.4444
# epoch:54, tr_loss:0.2609, tr_acc:0.8889,   val_loss:0.4830, val_acc:0.4444
# epoch:55, tr_loss:0.2428, tr_acc:0.9167,   val_loss:0.4928, val_acc:0.4444
# epoch:56, tr_loss:0.2235, tr_acc:0.9167,   val_loss:0.5355, val_acc:0.4444
# epoch:57, tr_loss:0.2059, tr_acc:0.9444,   val_loss:0.5399, val_acc:0.4444
# epoch:58, tr_loss:0.2343, tr_acc:0.8889,   val_loss:0.5388, val_acc:0.4444
# epoch:59, tr_loss:0.2173, tr_acc:0.9167,   val_loss:0.5685, val_acc:0.4444
# epoch:60, tr_loss:0.2072, tr_acc:0.9444,   val_loss:0.5730, val_acc:0.4444
# epoch:61, tr_loss:0.2482, tr_acc:0.9167,   val_loss:0.5628, val_acc:0.4444
# epoch:62, tr_loss:0.2130, tr_acc:0.9167,   val_loss:0.5304, val_acc:0.4444
# epoch:63, tr_loss:0.2150, tr_acc:0.9167,   val_loss:0.5438, val_acc:0.4444
# epoch:64, tr_loss:0.2241, tr_acc:0.9167,   val_loss:0.5661, val_acc:0.4444
# epoch:65, tr_loss:0.2421, tr_acc:0.8889,   val_loss:0.5595, val_acc:0.4444
# epoch:66, tr_loss:0.3208, tr_acc:0.8333,   val_loss:0.5802, val_acc:0.4444
# epoch:67, tr_loss:0.1542, tr_acc:0.9444,   val_loss:0.6164, val_acc:0.4444
# epoch:68, tr_loss:0.3267, tr_acc:0.8333,   val_loss:0.6371, val_acc:0.4444
# epoch:69, tr_loss:0.2008, tr_acc:0.9444,   val_loss:0.6125, val_acc:0.4444
# epoch:70, tr_loss:0.2348, tr_acc:0.8889,   val_loss:0.6009, val_acc:0.5556
# epoch:71, tr_loss:0.2113, tr_acc:0.9444,   val_loss:0.5968, val_acc:0.4444
# epoch:72, tr_loss:0.2565, tr_acc:0.8889,   val_loss:0.5698, val_acc:0.4444
# epoch:73, tr_loss:0.2080, tr_acc:0.9444,   val_loss:0.5630, val_acc:0.4444
# epoch:74, tr_loss:0.2209, tr_acc:0.9167,   val_loss:0.5785, val_acc:0.4444
# epoch:75, tr_loss:0.2233, tr_acc:0.9167,   val_loss:0.6201, val_acc:0.4444
# epoch:76, tr_loss:0.1481, tr_acc:0.9722,   val_loss:0.6304, val_acc:0.4444
# epoch:77, tr_loss:0.1551, tr_acc:0.9722,   val_loss:0.6246, val_acc:0.4444
# epoch:78, tr_loss:0.1403, tr_acc:0.9444,   val_loss:0.6127, val_acc:0.4444
# epoch:79, tr_loss:0.1259, tr_acc:0.9722,   val_loss:0.6132, val_acc:0.4444
# epoch:80, tr_loss:0.1465, tr_acc:0.9722,   val_loss:0.6263, val_acc:0.4444
# epoch:81, tr_loss:0.1737, tr_acc:0.9167,   val_loss:0.6091, val_acc:0.5556
# epoch:82, tr_loss:0.1424, tr_acc:0.9722,   val_loss:0.6052, val_acc:0.5556
# epoch:83, tr_loss:0.1447, tr_acc:0.9722,   val_loss:0.6212, val_acc:0.4444
# epoch:84, tr_loss:0.2118, tr_acc:0.8889,   val_loss:0.6395, val_acc:0.4444
# epoch:85, tr_loss:0.1273, tr_acc:1.0000,   val_loss:0.6277, val_acc:0.4444
# epoch:86, tr_loss:0.1527, tr_acc:0.9722,   val_loss:0.5841, val_acc:0.4444
# epoch:87, tr_loss:0.1589, tr_acc:0.9167,   val_loss:0.5792, val_acc:0.5556
# epoch:88, tr_loss:0.1974, tr_acc:0.8611,   val_loss:0.5389, val_acc:0.5556
# epoch:89, tr_loss:0.2090, tr_acc:0.8889,   val_loss:0.5407, val_acc:0.5556
# epoch:90, tr_loss:0.1561, tr_acc:0.8889,   val_loss:0.5677, val_acc:0.5556
# epoch:91, tr_loss:0.1401, tr_acc:0.9722,   val_loss:0.5609, val_acc:0.5556
# epoch:92, tr_loss:0.1889, tr_acc:0.9167,   val_loss:0.5866, val_acc:0.4444
# epoch:93, tr_loss:0.1513, tr_acc:0.9722,   val_loss:0.4901, val_acc:0.6667
# epoch:94, tr_loss:0.1966, tr_acc:0.8889,   val_loss:0.5365, val_acc:0.6667
# epoch:95, tr_loss:0.1616, tr_acc:0.9722,   val_loss:0.6385, val_acc:0.4444
# epoch:96, tr_loss:0.1327, tr_acc:0.9444,   val_loss:0.6555, val_acc:0.4444
# epoch:97, tr_loss:0.1192, tr_acc:0.9722,   val_loss:0.6919, val_acc:0.4444
# epoch:98, tr_loss:0.1472, tr_acc:0.9444,   val_loss:0.7366, val_acc:0.4444
# epoch:99, tr_loss:0.2416, tr_acc:0.8889,   val_loss:0.7493, val_acc:0.4444
# epoch:100, tr_loss:0.1258, tr_acc:0.9722,   val_loss:0.6984, val_acc:0.4444
# ----------finish training---------
# training_best_acc:1.0, val_best_acc:0.6666666666666666
# ----------start training----------
# epoch:1, tr_loss:0.5469, tr_acc:0.5556,   val_loss:0.3329, val_acc:0.6667
# epoch:2, tr_loss:0.5241, tr_acc:0.6111,   val_loss:0.3398, val_acc:0.6667
# epoch:3, tr_loss:0.5277, tr_acc:0.5000,   val_loss:0.3343, val_acc:0.6667
# epoch:4, tr_loss:0.5242, tr_acc:0.5556,   val_loss:0.3315, val_acc:0.6667
# epoch:5, tr_loss:0.5248, tr_acc:0.6389,   val_loss:0.3338, val_acc:0.5556
# epoch:6, tr_loss:0.5223, tr_acc:0.6389,   val_loss:0.3361, val_acc:0.5556
# epoch:7, tr_loss:0.5038, tr_acc:0.6944,   val_loss:0.3385, val_acc:0.5556
# epoch:8, tr_loss:0.5093, tr_acc:0.6944,   val_loss:0.3397, val_acc:0.5556
# epoch:9, tr_loss:0.5025, tr_acc:0.6944,   val_loss:0.3372, val_acc:0.5556
# epoch:10, tr_loss:0.4939, tr_acc:0.6389,   val_loss:0.3358, val_acc:0.5556
# epoch:11, tr_loss:0.5198, tr_acc:0.6389,   val_loss:0.3362, val_acc:0.5556
# epoch:12, tr_loss:0.5013, tr_acc:0.6667,   val_loss:0.3371, val_acc:0.5556
# epoch:13, tr_loss:0.4914, tr_acc:0.7222,   val_loss:0.3389, val_acc:0.5556
# epoch:14, tr_loss:0.5088, tr_acc:0.7500,   val_loss:0.3417, val_acc:0.5556
# epoch:15, tr_loss:0.4614, tr_acc:0.7222,   val_loss:0.3534, val_acc:0.5556
# epoch:16, tr_loss:0.4924, tr_acc:0.7500,   val_loss:0.3582, val_acc:0.5556
# epoch:17, tr_loss:0.4630, tr_acc:0.6944,   val_loss:0.3657, val_acc:0.5556
# epoch:18, tr_loss:0.4587, tr_acc:0.7222,   val_loss:0.3784, val_acc:0.5556
# epoch:19, tr_loss:0.4445, tr_acc:0.7778,   val_loss:0.3676, val_acc:0.5556
# epoch:20, tr_loss:0.4890, tr_acc:0.6389,   val_loss:0.3577, val_acc:0.5556
# epoch:21, tr_loss:0.4535, tr_acc:0.8056,   val_loss:0.3659, val_acc:0.6667
# epoch:22, tr_loss:0.4673, tr_acc:0.7500,   val_loss:0.3827, val_acc:0.5556
# epoch:23, tr_loss:0.4740, tr_acc:0.6667,   val_loss:0.3756, val_acc:0.6667
# epoch:24, tr_loss:0.4397, tr_acc:0.7222,   val_loss:0.3926, val_acc:0.5556
# epoch:25, tr_loss:0.4077, tr_acc:0.6944,   val_loss:0.4095, val_acc:0.4444
# epoch:26, tr_loss:0.4361, tr_acc:0.7778,   val_loss:0.4153, val_acc:0.4444
# epoch:27, tr_loss:0.4228, tr_acc:0.8056,   val_loss:0.4307, val_acc:0.4444
# epoch:28, tr_loss:0.3724, tr_acc:0.8889,   val_loss:0.4176, val_acc:0.2222
# epoch:29, tr_loss:0.4181, tr_acc:0.8333,   val_loss:0.4140, val_acc:0.2222
# epoch:30, tr_loss:0.3748, tr_acc:0.8611,   val_loss:0.4183, val_acc:0.3333
# epoch:31, tr_loss:0.3625, tr_acc:0.8889,   val_loss:0.4375, val_acc:0.4444
# epoch:32, tr_loss:0.3555, tr_acc:0.8611,   val_loss:0.4646, val_acc:0.4444
# epoch:33, tr_loss:0.3603, tr_acc:0.8889,   val_loss:0.4948, val_acc:0.4444
# epoch:34, tr_loss:0.3679, tr_acc:0.7778,   val_loss:0.5309, val_acc:0.3333
# epoch:35, tr_loss:0.3230, tr_acc:0.9167,   val_loss:0.5088, val_acc:0.2222
# epoch:36, tr_loss:0.3169, tr_acc:0.9167,   val_loss:0.5505, val_acc:0.3333
# epoch:37, tr_loss:0.2907, tr_acc:0.9722,   val_loss:0.5507, val_acc:0.3333
# epoch:38, tr_loss:0.3451, tr_acc:0.8611,   val_loss:0.5450, val_acc:0.5556
# epoch:39, tr_loss:0.2840, tr_acc:0.9167,   val_loss:0.5406, val_acc:0.4444
# epoch:40, tr_loss:0.2939, tr_acc:0.9167,   val_loss:0.5374, val_acc:0.4444
# epoch:41, tr_loss:0.2742, tr_acc:0.8889,   val_loss:0.5532, val_acc:0.4444
# epoch:42, tr_loss:0.2818, tr_acc:0.9444,   val_loss:0.5677, val_acc:0.4444
# epoch:43, tr_loss:0.2977, tr_acc:0.8611,   val_loss:0.5686, val_acc:0.4444
# epoch:44, tr_loss:0.2504, tr_acc:0.9167,   val_loss:0.6118, val_acc:0.4444
# epoch:45, tr_loss:0.2359, tr_acc:0.9444,   val_loss:0.6303, val_acc:0.5556
# epoch:46, tr_loss:0.2686, tr_acc:0.9167,   val_loss:0.6714, val_acc:0.4444
# epoch:47, tr_loss:0.2757, tr_acc:0.9167,   val_loss:0.6721, val_acc:0.3333
# epoch:48, tr_loss:0.2370, tr_acc:0.9444,   val_loss:0.6568, val_acc:0.3333
# epoch:49, tr_loss:0.2509, tr_acc:0.9444,   val_loss:0.5890, val_acc:0.3333
# epoch:50, tr_loss:0.3291, tr_acc:0.8611,   val_loss:0.5110, val_acc:0.4444
# epoch:51, tr_loss:0.2268, tr_acc:0.9722,   val_loss:0.4710, val_acc:0.4444
# epoch:52, tr_loss:0.2173, tr_acc:0.9444,   val_loss:0.4873, val_acc:0.4444
# epoch:53, tr_loss:0.2818, tr_acc:0.8889,   val_loss:0.4954, val_acc:0.4444
# epoch:54, tr_loss:0.1639, tr_acc:1.0000,   val_loss:0.4612, val_acc:0.5556
# epoch:55, tr_loss:0.2477, tr_acc:0.8889,   val_loss:0.4694, val_acc:0.5556
# epoch:56, tr_loss:0.1887, tr_acc:0.9444,   val_loss:0.4651, val_acc:0.5556
# epoch:57, tr_loss:0.1836, tr_acc:1.0000,   val_loss:0.4990, val_acc:0.4444
# epoch:58, tr_loss:0.2017, tr_acc:0.9444,   val_loss:0.5777, val_acc:0.4444
# epoch:59, tr_loss:0.2292, tr_acc:0.8611,   val_loss:0.5843, val_acc:0.5556
# epoch:60, tr_loss:0.2351, tr_acc:0.9167,   val_loss:0.5756, val_acc:0.5556
# epoch:61, tr_loss:0.1594, tr_acc:0.9444,   val_loss:0.5435, val_acc:0.4444
# epoch:62, tr_loss:0.2364, tr_acc:0.9444,   val_loss:0.5084, val_acc:0.4444
# epoch:63, tr_loss:0.1658, tr_acc:1.0000,   val_loss:0.5044, val_acc:0.4444
# epoch:64, tr_loss:0.2001, tr_acc:0.8889,   val_loss:0.5469, val_acc:0.5556
# epoch:65, tr_loss:0.2699, tr_acc:0.9167,   val_loss:0.5491, val_acc:0.5556
# epoch:66, tr_loss:0.2723, tr_acc:0.8889,   val_loss:0.5393, val_acc:0.5556
# epoch:67, tr_loss:0.1737, tr_acc:0.9722,   val_loss:0.6161, val_acc:0.3333
# epoch:68, tr_loss:0.1717, tr_acc:0.9722,   val_loss:0.7061, val_acc:0.3333
# epoch:69, tr_loss:0.2472, tr_acc:0.9444,   val_loss:0.6855, val_acc:0.4444
# epoch:70, tr_loss:0.1249, tr_acc:0.9722,   val_loss:0.6684, val_acc:0.4444
# epoch:71, tr_loss:0.1830, tr_acc:0.9167,   val_loss:0.6774, val_acc:0.4444
# epoch:72, tr_loss:0.1654, tr_acc:0.9444,   val_loss:0.6126, val_acc:0.4444
# epoch:73, tr_loss:0.3530, tr_acc:0.8333,   val_loss:0.6101, val_acc:0.4444
# epoch:74, tr_loss:0.2004, tr_acc:0.9444,   val_loss:0.5937, val_acc:0.4444
# epoch:75, tr_loss:0.1152, tr_acc:1.0000,   val_loss:0.5520, val_acc:0.6667
# epoch:76, tr_loss:0.1043, tr_acc:1.0000,   val_loss:0.5454, val_acc:0.6667
# epoch:77, tr_loss:0.1600, tr_acc:0.9444,   val_loss:0.5767, val_acc:0.5556
# epoch:78, tr_loss:0.1972, tr_acc:0.8889,   val_loss:0.6202, val_acc:0.4444
# epoch:79, tr_loss:0.1241, tr_acc:1.0000,   val_loss:0.7009, val_acc:0.4444
# epoch:80, tr_loss:0.1559, tr_acc:0.9722,   val_loss:0.7415, val_acc:0.5556
# epoch:81, tr_loss:0.1833, tr_acc:0.9444,   val_loss:0.7443, val_acc:0.5556
# epoch:82, tr_loss:0.1846, tr_acc:0.9444,   val_loss:0.7577, val_acc:0.4444
# epoch:83, tr_loss:0.2303, tr_acc:0.9444,   val_loss:0.7619, val_acc:0.4444
# epoch:84, tr_loss:0.1162, tr_acc:0.9444,   val_loss:0.7513, val_acc:0.4444
# epoch:85, tr_loss:0.1387, tr_acc:0.9444,   val_loss:0.7686, val_acc:0.5556
# epoch:86, tr_loss:0.1309, tr_acc:0.9722,   val_loss:0.6717, val_acc:0.4444
# epoch:87, tr_loss:0.1650, tr_acc:0.9722,   val_loss:0.5895, val_acc:0.5556
# epoch:88, tr_loss:0.1719, tr_acc:0.9444,   val_loss:0.6061, val_acc:0.5556
# epoch:89, tr_loss:0.1398, tr_acc:0.9167,   val_loss:0.6147, val_acc:0.5556
# epoch:90, tr_loss:0.1059, tr_acc:0.9722,   val_loss:0.6505, val_acc:0.5556
# epoch:91, tr_loss:0.0918, tr_acc:1.0000,   val_loss:0.6550, val_acc:0.5556
# epoch:92, tr_loss:0.0831, tr_acc:1.0000,   val_loss:0.6284, val_acc:0.5556
# epoch:93, tr_loss:0.1274, tr_acc:0.9167,   val_loss:0.6510, val_acc:0.5556
# epoch:94, tr_loss:0.2144, tr_acc:0.9444,   val_loss:0.6317, val_acc:0.5556
# epoch:95, tr_loss:0.1010, tr_acc:0.9444,   val_loss:0.4633, val_acc:0.6667
# epoch:96, tr_loss:0.1829, tr_acc:0.8611,   val_loss:0.4595, val_acc:0.6667
# epoch:97, tr_loss:0.1717, tr_acc:0.9167,   val_loss:0.4503, val_acc:0.6667
# epoch:98, tr_loss:0.1686, tr_acc:0.9167,   val_loss:0.5353, val_acc:0.5556
# epoch:99, tr_loss:0.1908, tr_acc:0.8889,   val_loss:0.5865, val_acc:0.5556
# epoch:100, tr_loss:0.1228, tr_acc:0.9722,   val_loss:0.5412, val_acc:0.5556
# ----------finish training---------
# training_best_acc:1.0, val_best_acc:0.6666666666666666
# ----------start training----------
# epoch:1, tr_loss:0.5467, tr_acc:0.4722,   val_loss:0.3312, val_acc:0.5556
# epoch:2, tr_loss:0.5335, tr_acc:0.5833,   val_loss:0.3366, val_acc:0.5556
# epoch:3, tr_loss:0.5295, tr_acc:0.5556,   val_loss:0.3370, val_acc:0.5556
# epoch:4, tr_loss:0.5389, tr_acc:0.6389,   val_loss:0.3375, val_acc:0.5556
# epoch:5, tr_loss:0.5321, tr_acc:0.6389,   val_loss:0.3361, val_acc:0.5556
# epoch:6, tr_loss:0.5279, tr_acc:0.6389,   val_loss:0.3349, val_acc:0.6667
# epoch:7, tr_loss:0.5045, tr_acc:0.6944,   val_loss:0.3329, val_acc:0.6667
# epoch:8, tr_loss:0.5122, tr_acc:0.6667,   val_loss:0.3308, val_acc:0.6667
# epoch:9, tr_loss:0.5080, tr_acc:0.6667,   val_loss:0.3289, val_acc:0.6667
# epoch:10, tr_loss:0.5151, tr_acc:0.6944,   val_loss:0.3263, val_acc:0.6667
# epoch:11, tr_loss:0.4906, tr_acc:0.7778,   val_loss:0.3239, val_acc:0.6667
# epoch:12, tr_loss:0.4869, tr_acc:0.8333,   val_loss:0.3219, val_acc:0.6667
# epoch:13, tr_loss:0.4997, tr_acc:0.6667,   val_loss:0.3232, val_acc:0.6667
# epoch:14, tr_loss:0.4687, tr_acc:0.6944,   val_loss:0.3240, val_acc:0.6667
# epoch:15, tr_loss:0.5147, tr_acc:0.6667,   val_loss:0.3260, val_acc:0.6667
# epoch:16, tr_loss:0.4570, tr_acc:0.8333,   val_loss:0.3267, val_acc:0.6667
# epoch:17, tr_loss:0.4586, tr_acc:0.8333,   val_loss:0.3269, val_acc:0.6667
# epoch:18, tr_loss:0.4875, tr_acc:0.8056,   val_loss:0.3218, val_acc:0.6667
# epoch:19, tr_loss:0.5051, tr_acc:0.7222,   val_loss:0.3203, val_acc:0.6667
# epoch:20, tr_loss:0.4646, tr_acc:0.7778,   val_loss:0.3200, val_acc:0.6667
# epoch:21, tr_loss:0.4365, tr_acc:0.8333,   val_loss:0.3236, val_acc:0.6667
# epoch:22, tr_loss:0.4539, tr_acc:0.7778,   val_loss:0.3211, val_acc:0.6667
# epoch:23, tr_loss:0.4460, tr_acc:0.8056,   val_loss:0.3184, val_acc:0.6667
# epoch:24, tr_loss:0.4319, tr_acc:0.8056,   val_loss:0.3166, val_acc:0.6667
# epoch:25, tr_loss:0.4659, tr_acc:0.7222,   val_loss:0.3193, val_acc:0.6667
# epoch:26, tr_loss:0.4229, tr_acc:0.8889,   val_loss:0.3212, val_acc:0.6667
# epoch:27, tr_loss:0.4129, tr_acc:0.8611,   val_loss:0.3271, val_acc:0.6667
# epoch:28, tr_loss:0.4181, tr_acc:0.8056,   val_loss:0.3294, val_acc:0.5556
# epoch:29, tr_loss:0.3847, tr_acc:0.9167,   val_loss:0.3199, val_acc:0.6667
# epoch:30, tr_loss:0.4298, tr_acc:0.8333,   val_loss:0.3292, val_acc:0.6667
# epoch:31, tr_loss:0.4067, tr_acc:0.8333,   val_loss:0.3404, val_acc:0.5556
# epoch:32, tr_loss:0.3572, tr_acc:0.8333,   val_loss:0.3364, val_acc:0.5556
# epoch:33, tr_loss:0.3551, tr_acc:0.9167,   val_loss:0.3242, val_acc:0.6667
# epoch:34, tr_loss:0.3875, tr_acc:0.8611,   val_loss:0.3173, val_acc:0.6667
# epoch:35, tr_loss:0.3798, tr_acc:0.8333,   val_loss:0.3277, val_acc:0.6667
# epoch:36, tr_loss:0.3387, tr_acc:0.8333,   val_loss:0.3447, val_acc:0.5556
# epoch:37, tr_loss:0.3447, tr_acc:0.9167,   val_loss:0.3448, val_acc:0.6667
# epoch:38, tr_loss:0.3452, tr_acc:0.8333,   val_loss:0.3448, val_acc:0.6667
# epoch:39, tr_loss:0.3221, tr_acc:0.8889,   val_loss:0.3546, val_acc:0.6667
# epoch:40, tr_loss:0.3047, tr_acc:0.8611,   val_loss:0.3506, val_acc:0.6667
# epoch:41, tr_loss:0.2992, tr_acc:0.9167,   val_loss:0.3522, val_acc:0.6667
# epoch:42, tr_loss:0.3035, tr_acc:0.8889,   val_loss:0.3710, val_acc:0.5556
# epoch:43, tr_loss:0.2509, tr_acc:0.9722,   val_loss:0.3799, val_acc:0.5556
# epoch:44, tr_loss:0.2321, tr_acc:0.9722,   val_loss:0.3897, val_acc:0.5556
# epoch:45, tr_loss:0.2596, tr_acc:0.9444,   val_loss:0.3913, val_acc:0.4444
# epoch:46, tr_loss:0.2411, tr_acc:0.9444,   val_loss:0.3910, val_acc:0.4444
# epoch:47, tr_loss:0.2045, tr_acc:0.9444,   val_loss:0.3965, val_acc:0.4444
# epoch:48, tr_loss:0.2599, tr_acc:0.8889,   val_loss:0.4113, val_acc:0.5556
# epoch:49, tr_loss:0.2057, tr_acc:0.9167,   val_loss:0.4107, val_acc:0.5556
# epoch:50, tr_loss:0.1944, tr_acc:0.9444,   val_loss:0.4140, val_acc:0.5556
# epoch:51, tr_loss:0.2163, tr_acc:0.9444,   val_loss:0.4240, val_acc:0.5556
# epoch:52, tr_loss:0.1981, tr_acc:0.9444,   val_loss:0.4306, val_acc:0.4444
# epoch:53, tr_loss:0.2028, tr_acc:0.9444,   val_loss:0.3962, val_acc:0.5556
# epoch:54, tr_loss:0.2029, tr_acc:0.9444,   val_loss:0.4852, val_acc:0.4444
# epoch:55, tr_loss:0.1886, tr_acc:0.9722,   val_loss:0.5200, val_acc:0.4444
# epoch:56, tr_loss:0.1963, tr_acc:0.9167,   val_loss:0.4609, val_acc:0.5556
# epoch:57, tr_loss:0.2549, tr_acc:0.9444,   val_loss:0.4816, val_acc:0.5556
# epoch:58, tr_loss:0.1835, tr_acc:0.9167,   val_loss:0.4953, val_acc:0.4444
# epoch:59, tr_loss:0.1901, tr_acc:0.9444,   val_loss:0.4784, val_acc:0.4444
# epoch:60, tr_loss:0.1864, tr_acc:0.9444,   val_loss:0.4493, val_acc:0.5556
# epoch:61, tr_loss:0.2005, tr_acc:0.9444,   val_loss:0.4548, val_acc:0.5556
# epoch:62, tr_loss:0.1529, tr_acc:0.9444,   val_loss:0.4642, val_acc:0.5556
# epoch:63, tr_loss:0.1736, tr_acc:0.9167,   val_loss:0.5051, val_acc:0.4444
# epoch:64, tr_loss:0.1648, tr_acc:0.9722,   val_loss:0.5441, val_acc:0.4444
# epoch:65, tr_loss:0.1476, tr_acc:0.9444,   val_loss:0.5502, val_acc:0.4444
# epoch:66, tr_loss:0.1421, tr_acc:1.0000,   val_loss:0.5150, val_acc:0.4444
# epoch:67, tr_loss:0.1483, tr_acc:0.9444,   val_loss:0.4833, val_acc:0.5556
# epoch:68, tr_loss:0.1098, tr_acc:1.0000,   val_loss:0.4858, val_acc:0.5556
# epoch:69, tr_loss:0.1230, tr_acc:0.9722,   val_loss:0.5099, val_acc:0.6667
# epoch:70, tr_loss:0.0985, tr_acc:0.9722,   val_loss:0.6058, val_acc:0.4444
# epoch:71, tr_loss:0.1721, tr_acc:0.8889,   val_loss:0.5199, val_acc:0.6667
# epoch:72, tr_loss:0.1281, tr_acc:0.9444,   val_loss:0.5102, val_acc:0.5556
# epoch:73, tr_loss:0.1564, tr_acc:0.9167,   val_loss:0.5621, val_acc:0.4444
# epoch:74, tr_loss:0.1102, tr_acc:1.0000,   val_loss:0.6103, val_acc:0.4444
# epoch:75, tr_loss:0.1650, tr_acc:0.9444,   val_loss:0.6040, val_acc:0.4444
# epoch:76, tr_loss:0.1301, tr_acc:0.9722,   val_loss:0.6011, val_acc:0.4444
# epoch:77, tr_loss:0.1431, tr_acc:0.9444,   val_loss:0.5904, val_acc:0.4444
# epoch:78, tr_loss:0.1181, tr_acc:1.0000,   val_loss:0.5374, val_acc:0.4444
# epoch:79, tr_loss:0.0860, tr_acc:1.0000,   val_loss:0.4713, val_acc:0.6667
# epoch:80, tr_loss:0.0633, tr_acc:1.0000,   val_loss:0.4620, val_acc:0.6667
# epoch:81, tr_loss:0.1389, tr_acc:0.9444,   val_loss:0.6657, val_acc:0.4444
# epoch:82, tr_loss:0.1677, tr_acc:0.9444,   val_loss:0.7058, val_acc:0.4444
# epoch:83, tr_loss:0.1503, tr_acc:0.9444,   val_loss:0.5396, val_acc:0.5556
# epoch:84, tr_loss:0.1463, tr_acc:0.9722,   val_loss:0.4987, val_acc:0.6667
# epoch:85, tr_loss:0.0822, tr_acc:0.9722,   val_loss:0.6244, val_acc:0.4444
# epoch:86, tr_loss:0.1255, tr_acc:0.9722,   val_loss:0.6252, val_acc:0.4444
# epoch:87, tr_loss:0.1485, tr_acc:0.9444,   val_loss:0.5735, val_acc:0.6667
# epoch:88, tr_loss:0.1459, tr_acc:0.9722,   val_loss:0.5785, val_acc:0.6667
# epoch:89, tr_loss:0.1722, tr_acc:0.9167,   val_loss:0.5946, val_acc:0.6667
# epoch:90, tr_loss:0.0872, tr_acc:0.9722,   val_loss:0.5985, val_acc:0.6667
# epoch:91, tr_loss:0.1156, tr_acc:0.9444,   val_loss:0.5620, val_acc:0.6667
# epoch:92, tr_loss:0.0850, tr_acc:1.0000,   val_loss:0.5628, val_acc:0.6667
# epoch:93, tr_loss:0.1873, tr_acc:0.9167,   val_loss:0.5807, val_acc:0.6667
# epoch:94, tr_loss:0.0881, tr_acc:0.9722,   val_loss:0.6095, val_acc:0.6667
# epoch:95, tr_loss:0.0777, tr_acc:0.9722,   val_loss:0.6118, val_acc:0.6667
# epoch:96, tr_loss:0.1421, tr_acc:0.9722,   val_loss:0.6065, val_acc:0.6667
# epoch:97, tr_loss:0.1329, tr_acc:0.9722,   val_loss:0.6652, val_acc:0.5556
# epoch:98, tr_loss:0.1087, tr_acc:0.9444,   val_loss:0.5690, val_acc:0.6667
# epoch:99, tr_loss:0.1075, tr_acc:0.9444,   val_loss:0.5824, val_acc:0.6667
# epoch:100, tr_loss:0.1223, tr_acc:0.9444,   val_loss:0.6604, val_acc:0.5556
# ----------finish training---------
# training_best_acc:1.0, val_best_acc:0.6666666666666666
# ----------start training----------
# epoch:1, tr_loss:0.5711, tr_acc:0.5000,   val_loss:0.3349, val_acc:0.6667
# epoch:2, tr_loss:0.5457, tr_acc:0.5278,   val_loss:0.3309, val_acc:0.6667
# epoch:3, tr_loss:0.5702, tr_acc:0.5278,   val_loss:0.3290, val_acc:0.6667
# epoch:4, tr_loss:0.5267, tr_acc:0.5278,   val_loss:0.3267, val_acc:0.7778
# epoch:5, tr_loss:0.5187, tr_acc:0.6111,   val_loss:0.3265, val_acc:0.7778
# epoch:6, tr_loss:0.5566, tr_acc:0.5833,   val_loss:0.3269, val_acc:0.7778
# epoch:7, tr_loss:0.5350, tr_acc:0.6389,   val_loss:0.3275, val_acc:0.7778
# epoch:8, tr_loss:0.5178, tr_acc:0.6111,   val_loss:0.3283, val_acc:0.7778
# epoch:9, tr_loss:0.5228, tr_acc:0.6111,   val_loss:0.3286, val_acc:0.7778
# epoch:10, tr_loss:0.5090, tr_acc:0.6389,   val_loss:0.3292, val_acc:0.7778
# epoch:11, tr_loss:0.4971, tr_acc:0.6667,   val_loss:0.3282, val_acc:0.7778
# epoch:12, tr_loss:0.4984, tr_acc:0.6389,   val_loss:0.3259, val_acc:0.7778
# epoch:13, tr_loss:0.5297, tr_acc:0.6111,   val_loss:0.3237, val_acc:0.7778
# epoch:14, tr_loss:0.5120, tr_acc:0.7222,   val_loss:0.3231, val_acc:0.7778
# epoch:15, tr_loss:0.5154, tr_acc:0.7500,   val_loss:0.3242, val_acc:0.7778
# epoch:16, tr_loss:0.5160, tr_acc:0.6389,   val_loss:0.3234, val_acc:0.7778
# epoch:17, tr_loss:0.4704, tr_acc:0.8611,   val_loss:0.3246, val_acc:0.7778
# epoch:18, tr_loss:0.4964, tr_acc:0.7222,   val_loss:0.3240, val_acc:0.7778
# epoch:19, tr_loss:0.4875, tr_acc:0.6667,   val_loss:0.3214, val_acc:0.7778
# epoch:20, tr_loss:0.4863, tr_acc:0.7500,   val_loss:0.3170, val_acc:0.7778
# epoch:21, tr_loss:0.4829, tr_acc:0.7500,   val_loss:0.3132, val_acc:0.7778
# epoch:22, tr_loss:0.4671, tr_acc:0.7500,   val_loss:0.3071, val_acc:0.7778
# epoch:23, tr_loss:0.4757, tr_acc:0.7222,   val_loss:0.3073, val_acc:0.7778
# epoch:24, tr_loss:0.4413, tr_acc:0.8056,   val_loss:0.3116, val_acc:0.7778
# epoch:25, tr_loss:0.4441, tr_acc:0.7500,   val_loss:0.3090, val_acc:0.7778
# epoch:26, tr_loss:0.4203, tr_acc:0.8056,   val_loss:0.2949, val_acc:0.7778
# epoch:27, tr_loss:0.4484, tr_acc:0.7778,   val_loss:0.2942, val_acc:0.7778
# epoch:28, tr_loss:0.3831, tr_acc:0.8889,   val_loss:0.3063, val_acc:0.7778
# epoch:29, tr_loss:0.4089, tr_acc:0.8611,   val_loss:0.2984, val_acc:0.7778
# epoch:30, tr_loss:0.4179, tr_acc:0.8333,   val_loss:0.2888, val_acc:0.7778
# epoch:31, tr_loss:0.4026, tr_acc:0.8333,   val_loss:0.3168, val_acc:0.7778
# epoch:32, tr_loss:0.4001, tr_acc:0.8056,   val_loss:0.2994, val_acc:0.7778
# epoch:33, tr_loss:0.3536, tr_acc:0.8611,   val_loss:0.2801, val_acc:0.6667
# epoch:34, tr_loss:0.4104, tr_acc:0.8056,   val_loss:0.2740, val_acc:0.7778
# epoch:35, tr_loss:0.3807, tr_acc:0.8611,   val_loss:0.2684, val_acc:0.7778
# epoch:36, tr_loss:0.3690, tr_acc:0.8611,   val_loss:0.2656, val_acc:0.7778
# epoch:37, tr_loss:0.3306, tr_acc:0.8611,   val_loss:0.2649, val_acc:0.7778
# epoch:38, tr_loss:0.3569, tr_acc:0.8611,   val_loss:0.2784, val_acc:0.7778
# epoch:39, tr_loss:0.3253, tr_acc:0.8611,   val_loss:0.2915, val_acc:0.7778
# epoch:40, tr_loss:0.3184, tr_acc:0.8611,   val_loss:0.2859, val_acc:0.7778
# epoch:41, tr_loss:0.3152, tr_acc:0.9722,   val_loss:0.2882, val_acc:0.7778
# epoch:42, tr_loss:0.3074, tr_acc:0.9167,   val_loss:0.2831, val_acc:0.7778
# epoch:43, tr_loss:0.2697, tr_acc:0.9444,   val_loss:0.2601, val_acc:0.7778
# epoch:44, tr_loss:0.2661, tr_acc:0.9444,   val_loss:0.2579, val_acc:0.7778
# epoch:45, tr_loss:0.2359, tr_acc:0.9444,   val_loss:0.2770, val_acc:0.7778
# epoch:46, tr_loss:0.2824, tr_acc:0.8889,   val_loss:0.2726, val_acc:0.7778
# epoch:47, tr_loss:0.2489, tr_acc:0.9444,   val_loss:0.2474, val_acc:0.7778
# epoch:48, tr_loss:0.2597, tr_acc:0.9167,   val_loss:0.2355, val_acc:0.7778
# epoch:49, tr_loss:0.2399, tr_acc:0.9722,   val_loss:0.2439, val_acc:0.7778
# epoch:50, tr_loss:0.2711, tr_acc:0.9444,   val_loss:0.2427, val_acc:0.7778
# epoch:51, tr_loss:0.2486, tr_acc:0.9167,   val_loss:0.2904, val_acc:0.7778
# epoch:52, tr_loss:0.2705, tr_acc:0.8333,   val_loss:0.2248, val_acc:0.8889
# epoch:53, tr_loss:0.2144, tr_acc:0.9444,   val_loss:0.2943, val_acc:0.6667
# epoch:54, tr_loss:0.1922, tr_acc:0.9444,   val_loss:0.3797, val_acc:0.5556
# epoch:55, tr_loss:0.2032, tr_acc:0.9444,   val_loss:0.3072, val_acc:0.6667
# epoch:56, tr_loss:0.2087, tr_acc:0.9722,   val_loss:0.2712, val_acc:0.7778
# epoch:57, tr_loss:0.2598, tr_acc:0.9167,   val_loss:0.2231, val_acc:0.8889
# epoch:58, tr_loss:0.2054, tr_acc:0.8611,   val_loss:0.2506, val_acc:0.7778
# epoch:59, tr_loss:0.2232, tr_acc:0.9444,   val_loss:0.2674, val_acc:0.6667
# epoch:60, tr_loss:0.2397, tr_acc:0.9167,   val_loss:0.2320, val_acc:0.8889
# epoch:61, tr_loss:0.2093, tr_acc:0.9444,   val_loss:0.2558, val_acc:0.7778
# epoch:62, tr_loss:0.2178, tr_acc:0.8611,   val_loss:0.3169, val_acc:0.6667
# epoch:63, tr_loss:0.1990, tr_acc:0.9722,   val_loss:0.3011, val_acc:0.6667
# epoch:64, tr_loss:0.2163, tr_acc:0.9167,   val_loss:0.2289, val_acc:0.8889
# epoch:65, tr_loss:0.1877, tr_acc:0.9167,   val_loss:0.2287, val_acc:0.8889
# epoch:66, tr_loss:0.2458, tr_acc:0.9444,   val_loss:0.2155, val_acc:0.8889
# epoch:67, tr_loss:0.1801, tr_acc:0.9722,   val_loss:0.4354, val_acc:0.5556
# epoch:68, tr_loss:0.2420, tr_acc:0.8889,   val_loss:0.6171, val_acc:0.4444
# epoch:69, tr_loss:0.1839, tr_acc:0.9444,   val_loss:0.3526, val_acc:0.5556
# epoch:70, tr_loss:0.1681, tr_acc:0.9722,   val_loss:0.2723, val_acc:0.7778
# epoch:71, tr_loss:0.2489, tr_acc:0.8611,   val_loss:0.3426, val_acc:0.5556
# epoch:72, tr_loss:0.3016, tr_acc:0.8611,   val_loss:0.4614, val_acc:0.4444
# epoch:73, tr_loss:0.1435, tr_acc:0.9722,   val_loss:0.5231, val_acc:0.4444
# epoch:74, tr_loss:0.1755, tr_acc:0.8889,   val_loss:0.4116, val_acc:0.5556
# epoch:75, tr_loss:0.1842, tr_acc:0.9167,   val_loss:0.2909, val_acc:0.8889
# epoch:76, tr_loss:0.1678, tr_acc:0.8889,   val_loss:0.2986, val_acc:0.7778
# epoch:77, tr_loss:0.1935, tr_acc:0.9167,   val_loss:0.3749, val_acc:0.7778
# epoch:78, tr_loss:0.1496, tr_acc:0.9444,   val_loss:0.6088, val_acc:0.4444
# epoch:79, tr_loss:0.1585, tr_acc:0.9444,   val_loss:0.5601, val_acc:0.4444
# epoch:80, tr_loss:0.1485, tr_acc:0.9444,   val_loss:0.2341, val_acc:0.8889
# epoch:81, tr_loss:0.1592, tr_acc:0.9444,   val_loss:0.2127, val_acc:0.8889
# epoch:82, tr_loss:0.1268, tr_acc:0.9444,   val_loss:0.2158, val_acc:0.8889
# epoch:83, tr_loss:0.1721, tr_acc:0.9444,   val_loss:0.2297, val_acc:0.8889
# epoch:84, tr_loss:0.1299, tr_acc:0.9444,   val_loss:0.2295, val_acc:0.8889
# epoch:85, tr_loss:0.1540, tr_acc:0.9167,   val_loss:0.5165, val_acc:0.5556
# epoch:86, tr_loss:0.1080, tr_acc:0.9444,   val_loss:0.4401, val_acc:0.5556
# epoch:87, tr_loss:0.0931, tr_acc:1.0000,   val_loss:0.2632, val_acc:0.7778
# epoch:88, tr_loss:0.1194, tr_acc:1.0000,   val_loss:0.2323, val_acc:0.8889
# epoch:89, tr_loss:0.1636, tr_acc:0.9444,   val_loss:0.2054, val_acc:0.8889
# epoch:90, tr_loss:0.1961, tr_acc:0.8889,   val_loss:0.2242, val_acc:0.8889
# epoch:91, tr_loss:0.1671, tr_acc:0.9444,   val_loss:0.2946, val_acc:0.6667
# epoch:92, tr_loss:0.1695, tr_acc:0.9722,   val_loss:0.5833, val_acc:0.5556
# epoch:93, tr_loss:0.2691, tr_acc:0.8889,   val_loss:0.5686, val_acc:0.5556
# epoch:94, tr_loss:0.1227, tr_acc:0.9722,   val_loss:0.4892, val_acc:0.5556
# epoch:95, tr_loss:0.0929, tr_acc:0.9722,   val_loss:0.3134, val_acc:0.7778
# epoch:96, tr_loss:0.0896, tr_acc:1.0000,   val_loss:0.2320, val_acc:0.8889
# epoch:97, tr_loss:0.1075, tr_acc:0.9722,   val_loss:0.2338, val_acc:0.8889
# epoch:98, tr_loss:0.1515, tr_acc:0.8889,   val_loss:0.5594, val_acc:0.5556
# epoch:99, tr_loss:0.0798, tr_acc:0.9722,   val_loss:0.7328, val_acc:0.4444
# epoch:100, tr_loss:0.0938, tr_acc:0.9722,   val_loss:0.4982, val_acc:0.5556
# ----------finish training---------
# training_best_acc:1.0, val_best_acc:0.8888888888888888
# subject1   mean_acc:0.7333333333333333, var_acc:0.007901234567901235
# Removing orphaned offset at the beginning of the file.
# 89 events found
# Events id: [1 2 3]
# 45 matching events found
# Not setting metadata
# Loading data for 45 events and 641 original time points ...
# 0 bad epochs dropped
# ----------start training----------
# epoch:1, tr_loss:0.5529, tr_acc:0.5556,   val_loss:0.3675, val_acc:0.3333
# epoch:2, tr_loss:0.5139, tr_acc:0.6389,   val_loss:0.3666, val_acc:0.2222
# epoch:3, tr_loss:0.5102, tr_acc:0.5833,   val_loss:0.3661, val_acc:0.3333
# epoch:4, tr_loss:0.5362, tr_acc:0.5278,   val_loss:0.3681, val_acc:0.3333
# epoch:5, tr_loss:0.5137, tr_acc:0.6111,   val_loss:0.3714, val_acc:0.3333
# epoch:6, tr_loss:0.5098, tr_acc:0.5833,   val_loss:0.3752, val_acc:0.3333
# epoch:7, tr_loss:0.5077, tr_acc:0.6667,   val_loss:0.3777, val_acc:0.3333
# epoch:8, tr_loss:0.5050, tr_acc:0.6111,   val_loss:0.3805, val_acc:0.3333
# epoch:9, tr_loss:0.4855, tr_acc:0.6944,   val_loss:0.3830, val_acc:0.2222
# epoch:10, tr_loss:0.4880, tr_acc:0.7222,   val_loss:0.3853, val_acc:0.2222
# epoch:11, tr_loss:0.4584, tr_acc:0.7222,   val_loss:0.3886, val_acc:0.2222
# epoch:12, tr_loss:0.4765, tr_acc:0.7500,   val_loss:0.3913, val_acc:0.2222
# epoch:13, tr_loss:0.4629, tr_acc:0.7500,   val_loss:0.3963, val_acc:0.1111
# epoch:14, tr_loss:0.4662, tr_acc:0.7778,   val_loss:0.4021, val_acc:0.1111
# epoch:15, tr_loss:0.4697, tr_acc:0.7778,   val_loss:0.4070, val_acc:0.1111
# epoch:16, tr_loss:0.4366, tr_acc:0.8333,   val_loss:0.4086, val_acc:0.1111
# epoch:17, tr_loss:0.4306, tr_acc:0.8056,   val_loss:0.4138, val_acc:0.1111
# epoch:18, tr_loss:0.4186, tr_acc:0.8889,   val_loss:0.4162, val_acc:0.1111
# epoch:19, tr_loss:0.4113, tr_acc:0.8056,   val_loss:0.4242, val_acc:0.2222
# epoch:20, tr_loss:0.3958, tr_acc:0.8333,   val_loss:0.4334, val_acc:0.2222
# epoch:21, tr_loss:0.4001, tr_acc:0.8333,   val_loss:0.4396, val_acc:0.2222
# epoch:22, tr_loss:0.4092, tr_acc:0.8333,   val_loss:0.4448, val_acc:0.2222
# epoch:23, tr_loss:0.3456, tr_acc:0.9444,   val_loss:0.4480, val_acc:0.2222
# epoch:24, tr_loss:0.3701, tr_acc:0.9167,   val_loss:0.4514, val_acc:0.2222
# epoch:25, tr_loss:0.3644, tr_acc:0.9167,   val_loss:0.4644, val_acc:0.2222
# epoch:26, tr_loss:0.3645, tr_acc:0.8889,   val_loss:0.4908, val_acc:0.2222
# epoch:27, tr_loss:0.3218, tr_acc:0.9444,   val_loss:0.5039, val_acc:0.2222
# epoch:28, tr_loss:0.3220, tr_acc:0.8611,   val_loss:0.5008, val_acc:0.2222
# epoch:29, tr_loss:0.3539, tr_acc:0.8611,   val_loss:0.4933, val_acc:0.2222
# epoch:30, tr_loss:0.2740, tr_acc:0.9444,   val_loss:0.5182, val_acc:0.2222
# epoch:31, tr_loss:0.3462, tr_acc:0.8333,   val_loss:0.5376, val_acc:0.2222
# epoch:32, tr_loss:0.3259, tr_acc:0.9167,   val_loss:0.5413, val_acc:0.2222
# epoch:33, tr_loss:0.3052, tr_acc:0.9444,   val_loss:0.5298, val_acc:0.2222
# epoch:34, tr_loss:0.2823, tr_acc:0.8889,   val_loss:0.5350, val_acc:0.3333
# epoch:35, tr_loss:0.2903, tr_acc:0.9722,   val_loss:0.5627, val_acc:0.2222
# epoch:36, tr_loss:0.2505, tr_acc:0.9722,   val_loss:0.5975, val_acc:0.2222
# epoch:37, tr_loss:0.2678, tr_acc:0.9444,   val_loss:0.6158, val_acc:0.2222
# epoch:38, tr_loss:0.1990, tr_acc:1.0000,   val_loss:0.6193, val_acc:0.2222
# epoch:39, tr_loss:0.2322, tr_acc:0.9722,   val_loss:0.6199, val_acc:0.2222
# epoch:40, tr_loss:0.1958, tr_acc:1.0000,   val_loss:0.6286, val_acc:0.2222
# epoch:41, tr_loss:0.1869, tr_acc:0.9722,   val_loss:0.6243, val_acc:0.2222
# epoch:42, tr_loss:0.1981, tr_acc:0.9722,   val_loss:0.6328, val_acc:0.3333
# epoch:43, tr_loss:0.1710, tr_acc:1.0000,   val_loss:0.6525, val_acc:0.3333
# epoch:44, tr_loss:0.1605, tr_acc:1.0000,   val_loss:0.6652, val_acc:0.3333
# epoch:45, tr_loss:0.1227, tr_acc:1.0000,   val_loss:0.6835, val_acc:0.3333
# epoch:46, tr_loss:0.1373, tr_acc:0.9722,   val_loss:0.6927, val_acc:0.3333
# epoch:47, tr_loss:0.1554, tr_acc:1.0000,   val_loss:0.7461, val_acc:0.2222
# epoch:48, tr_loss:0.1602, tr_acc:1.0000,   val_loss:0.7744, val_acc:0.2222
# epoch:49, tr_loss:0.1160, tr_acc:1.0000,   val_loss:0.7896, val_acc:0.2222
# epoch:50, tr_loss:0.1551, tr_acc:0.9722,   val_loss:0.7769, val_acc:0.2222
# epoch:51, tr_loss:0.1397, tr_acc:1.0000,   val_loss:0.6901, val_acc:0.3333
# epoch:52, tr_loss:0.1919, tr_acc:0.8889,   val_loss:0.6950, val_acc:0.3333
# epoch:53, tr_loss:0.1513, tr_acc:0.9722,   val_loss:0.7463, val_acc:0.2222
# epoch:54, tr_loss:0.1336, tr_acc:1.0000,   val_loss:0.7831, val_acc:0.2222
# epoch:55, tr_loss:0.1279, tr_acc:1.0000,   val_loss:0.8007, val_acc:0.2222
# epoch:56, tr_loss:0.1116, tr_acc:1.0000,   val_loss:0.7972, val_acc:0.2222
# epoch:57, tr_loss:0.1275, tr_acc:1.0000,   val_loss:0.8012, val_acc:0.2222
# epoch:58, tr_loss:0.1211, tr_acc:1.0000,   val_loss:0.8295, val_acc:0.2222
# epoch:59, tr_loss:0.1183, tr_acc:1.0000,   val_loss:0.8545, val_acc:0.2222
# epoch:60, tr_loss:0.1242, tr_acc:0.9722,   val_loss:0.8597, val_acc:0.2222
# epoch:61, tr_loss:0.0879, tr_acc:1.0000,   val_loss:0.8554, val_acc:0.3333
# epoch:62, tr_loss:0.0887, tr_acc:1.0000,   val_loss:0.8331, val_acc:0.3333
# epoch:63, tr_loss:0.1339, tr_acc:0.9722,   val_loss:0.8242, val_acc:0.3333
# epoch:64, tr_loss:0.0797, tr_acc:1.0000,   val_loss:0.8466, val_acc:0.3333
# epoch:65, tr_loss:0.1008, tr_acc:0.9722,   val_loss:0.9593, val_acc:0.2222
# epoch:66, tr_loss:0.0833, tr_acc:1.0000,   val_loss:0.9859, val_acc:0.2222
# epoch:67, tr_loss:0.0774, tr_acc:1.0000,   val_loss:0.9955, val_acc:0.2222
# epoch:68, tr_loss:0.0967, tr_acc:0.9722,   val_loss:0.9977, val_acc:0.2222
# epoch:69, tr_loss:0.0886, tr_acc:1.0000,   val_loss:0.9920, val_acc:0.2222
# epoch:70, tr_loss:0.0574, tr_acc:1.0000,   val_loss:1.0039, val_acc:0.2222
# epoch:71, tr_loss:0.0660, tr_acc:1.0000,   val_loss:1.0228, val_acc:0.2222
# epoch:72, tr_loss:0.0429, tr_acc:1.0000,   val_loss:1.0436, val_acc:0.2222
# epoch:73, tr_loss:0.0654, tr_acc:1.0000,   val_loss:1.0551, val_acc:0.2222
# epoch:74, tr_loss:0.0562, tr_acc:1.0000,   val_loss:1.0455, val_acc:0.2222
# epoch:75, tr_loss:0.0487, tr_acc:1.0000,   val_loss:1.0673, val_acc:0.2222
# epoch:76, tr_loss:0.0526, tr_acc:1.0000,   val_loss:1.0841, val_acc:0.2222
# epoch:77, tr_loss:0.0647, tr_acc:1.0000,   val_loss:1.0841, val_acc:0.2222
# epoch:78, tr_loss:0.0715, tr_acc:0.9722,   val_loss:1.0959, val_acc:0.2222
# epoch:79, tr_loss:0.0415, tr_acc:1.0000,   val_loss:1.1066, val_acc:0.2222
# epoch:80, tr_loss:0.0450, tr_acc:1.0000,   val_loss:1.1195, val_acc:0.2222
# epoch:81, tr_loss:0.0414, tr_acc:1.0000,   val_loss:1.1308, val_acc:0.3333
# epoch:82, tr_loss:0.0275, tr_acc:1.0000,   val_loss:1.1301, val_acc:0.3333
# epoch:83, tr_loss:0.0480, tr_acc:1.0000,   val_loss:1.1503, val_acc:0.3333
# epoch:84, tr_loss:0.0278, tr_acc:1.0000,   val_loss:1.1692, val_acc:0.3333
# epoch:85, tr_loss:0.0292, tr_acc:1.0000,   val_loss:1.1758, val_acc:0.3333
# epoch:86, tr_loss:0.0449, tr_acc:0.9722,   val_loss:1.1623, val_acc:0.3333
# epoch:87, tr_loss:0.0273, tr_acc:1.0000,   val_loss:1.1664, val_acc:0.3333
# epoch:88, tr_loss:0.0323, tr_acc:1.0000,   val_loss:1.1838, val_acc:0.3333
# epoch:89, tr_loss:0.0332, tr_acc:1.0000,   val_loss:1.1993, val_acc:0.3333
# epoch:90, tr_loss:0.0401, tr_acc:1.0000,   val_loss:1.1880, val_acc:0.3333
# epoch:91, tr_loss:0.0476, tr_acc:1.0000,   val_loss:1.1670, val_acc:0.3333
# epoch:92, tr_loss:0.0320, tr_acc:1.0000,   val_loss:1.1561, val_acc:0.3333
# epoch:93, tr_loss:0.0447, tr_acc:1.0000,   val_loss:1.1939, val_acc:0.3333
# epoch:94, tr_loss:0.0291, tr_acc:1.0000,   val_loss:1.2187, val_acc:0.3333
# epoch:95, tr_loss:0.0359, tr_acc:1.0000,   val_loss:1.2113, val_acc:0.3333
# epoch:96, tr_loss:0.0193, tr_acc:1.0000,   val_loss:1.1832, val_acc:0.3333
# epoch:97, tr_loss:0.0425, tr_acc:1.0000,   val_loss:1.1508, val_acc:0.3333
# epoch:98, tr_loss:0.0326, tr_acc:1.0000,   val_loss:1.1531, val_acc:0.3333
# epoch:99, tr_loss:0.0230, tr_acc:1.0000,   val_loss:1.1698, val_acc:0.3333
# epoch:100, tr_loss:0.0630, tr_acc:0.9722,   val_loss:1.2241, val_acc:0.3333
# ----------finish training---------
# training_best_acc:1.0, val_best_acc:0.3333333333333333
# ----------start training----------
# epoch:1, tr_loss:0.5570, tr_acc:0.4722,   val_loss:0.3493, val_acc:0.5556
# epoch:2, tr_loss:0.5555, tr_acc:0.5000,   val_loss:0.3449, val_acc:0.3333
# epoch:3, tr_loss:0.5428, tr_acc:0.5833,   val_loss:0.3438, val_acc:0.5556
# epoch:4, tr_loss:0.5425, tr_acc:0.6389,   val_loss:0.3428, val_acc:0.5556
# epoch:5, tr_loss:0.5251, tr_acc:0.7222,   val_loss:0.3415, val_acc:0.6667
# epoch:6, tr_loss:0.5200, tr_acc:0.7778,   val_loss:0.3423, val_acc:0.4444
# epoch:7, tr_loss:0.5239, tr_acc:0.7222,   val_loss:0.3442, val_acc:0.3333
# epoch:8, tr_loss:0.5302, tr_acc:0.5833,   val_loss:0.3455, val_acc:0.3333
# epoch:9, tr_loss:0.5394, tr_acc:0.6111,   val_loss:0.3468, val_acc:0.3333
# epoch:10, tr_loss:0.5250, tr_acc:0.7222,   val_loss:0.3474, val_acc:0.3333
# epoch:11, tr_loss:0.5176, tr_acc:0.6667,   val_loss:0.3495, val_acc:0.4444
# epoch:12, tr_loss:0.5141, tr_acc:0.7222,   val_loss:0.3520, val_acc:0.4444
# epoch:13, tr_loss:0.4954, tr_acc:0.7500,   val_loss:0.3572, val_acc:0.3333
# epoch:14, tr_loss:0.5038, tr_acc:0.7500,   val_loss:0.3611, val_acc:0.3333
# epoch:15, tr_loss:0.5156, tr_acc:0.6667,   val_loss:0.3634, val_acc:0.4444
# epoch:16, tr_loss:0.4832, tr_acc:0.7778,   val_loss:0.3670, val_acc:0.3333
# epoch:17, tr_loss:0.4738, tr_acc:0.8056,   val_loss:0.3698, val_acc:0.3333
# epoch:18, tr_loss:0.4892, tr_acc:0.8333,   val_loss:0.3678, val_acc:0.3333
# epoch:19, tr_loss:0.4589, tr_acc:0.8333,   val_loss:0.3662, val_acc:0.4444
# epoch:20, tr_loss:0.4813, tr_acc:0.6944,   val_loss:0.3717, val_acc:0.4444
# epoch:21, tr_loss:0.4526, tr_acc:0.7778,   val_loss:0.3755, val_acc:0.4444
# epoch:22, tr_loss:0.4330, tr_acc:0.8056,   val_loss:0.3791, val_acc:0.3333
# epoch:23, tr_loss:0.4372, tr_acc:0.8889,   val_loss:0.3870, val_acc:0.3333
# ...
# epoch:10, tr_loss:0.4500, tr_acc:0.8333,   val_loss:0.3553, val_acc:0.3333
# epoch:11, tr_loss:0.4447, tr_acc:0.8333,   val_loss:0.3604, val_acc:0.3333
# epoch:12, tr_loss:0.4605, tr_acc:0.6944,   val_loss:0.3677, val_acc:0.4444
# epoch:13, tr_loss:0.4551, tr_acc:0.7500,   val_loss:0.3684, val_acc:0.3333
# epoch:14, tr_loss:0.4330, tr_acc:0.8056,   val_loss:0.3805, val_acc:0.4444
# epoch:15, tr_loss:0.3805, tr_acc:0.9167,   val_loss:0.3830, val_acc:0.4444
# epoch:16, tr_loss:0.4066, tr_acc:0.8333,   val_loss:0.3982, val_acc:0.4444
# epoch:17, tr_loss:0.3758, tr_acc:0.8333,   val_loss:0.4161, val_acc:0.4444
# epoch:18, tr_loss:0.3670, tr_acc:0.8889,   val_loss:0.3992, val_acc:0.4444
# epoch:19, tr_loss:0.3748, tr_acc:0.8889,   val_loss:0.4055, val_acc:0.3333
# epoch:20, tr_loss:0.3392, tr_acc:0.9167,   val_loss:0.4398, val_acc:0.3333
# epoch:21, tr_loss:0.3407, tr_acc:0.8889,   val_loss:0.4920, val_acc:0.4444
# epoch:22, tr_loss:0.3333, tr_acc:0.8889,   val_loss:0.4542, val_acc:0.3333
# epoch:23, tr_loss:0.2711, tr_acc:0.9444,   val_loss:0.4475, val_acc:0.3333
# epoch:24, tr_loss:0.3101, tr_acc:0.9167,   val_loss:0.4524, val_acc:0.3333
# epoch:25, tr_loss:0.2797, tr_acc:0.9444,   val_loss:0.4813, val_acc:0.3333
# epoch:26, tr_loss:0.2519, tr_acc:0.9444,   val_loss:0.4764, val_acc:0.4444
# epoch:27, tr_loss:0.2630, tr_acc:0.9444,   val_loss:0.4701, val_acc:0.4444
# epoch:28, tr_loss:0.2815, tr_acc:0.9167,   val_loss:0.4650, val_acc:0.3333
# epoch:29, tr_loss:0.2487, tr_acc:0.9722,   val_loss:0.4700, val_acc:0.3333
# epoch:30, tr_loss:0.2419, tr_acc:0.9444,   val_loss:0.4636, val_acc:0.3333
# epoch:31, tr_loss:0.2806, tr_acc:0.8889,   val_loss:0.4782, val_acc:0.3333
# epoch:32, tr_loss:0.2745, tr_acc:0.9444,   val_loss:0.5086, val_acc:0.3333
# epoch:33, tr_loss:0.2339, tr_acc:0.8889,   val_loss:0.4748, val_acc:0.5556
# epoch:34, tr_loss:0.2105, tr_acc:1.0000,   val_loss:0.5165, val_acc:0.4444
# epoch:35, tr_loss:0.1932, tr_acc:1.0000,   val_loss:0.5284, val_acc:0.5556
# epoch:36, tr_loss:0.2146, tr_acc:0.8889,   val_loss:0.5454, val_acc:0.4444
# epoch:37, tr_loss:0.1910, tr_acc:1.0000,   val_loss:0.5836, val_acc:0.4444
# epoch:38, tr_loss:0.1286, tr_acc:0.9722,   val_loss:0.5882, val_acc:0.2222
# epoch:39, tr_loss:0.1176, tr_acc:0.9722,   val_loss:0.5961, val_acc:0.3333
# epoch:40, tr_loss:0.1322, tr_acc:0.9722,   val_loss:0.6037, val_acc:0.3333
# epoch:41, tr_loss:0.1008, tr_acc:1.0000,   val_loss:0.6004, val_acc:0.4444
# epoch:42, tr_loss:0.1216, tr_acc:1.0000,   val_loss:0.6448, val_acc:0.4444
# epoch:43, tr_loss:0.1591, tr_acc:0.9167,   val_loss:0.6737, val_acc:0.4444
# epoch:44, tr_loss:0.1126, tr_acc:1.0000,   val_loss:0.6156, val_acc:0.5556
# epoch:45, tr_loss:0.1233, tr_acc:0.9722,   val_loss:0.5951, val_acc:0.6667
# epoch:46, tr_loss:0.1180, tr_acc:1.0000,   val_loss:0.6015, val_acc:0.5556
# epoch:47, tr_loss:0.0864, tr_acc:1.0000,   val_loss:0.6263, val_acc:0.5556
# epoch:48, tr_loss:0.0927, tr_acc:1.0000,   val_loss:0.6371, val_acc:0.5556
# epoch:49, tr_loss:0.0831, tr_acc:1.0000,   val_loss:0.6520, val_acc:0.5556
# epoch:50, tr_loss:0.0871, tr_acc:1.0000,   val_loss:0.6494, val_acc:0.5556
# epoch:51, tr_loss:0.0706, tr_acc:1.0000,   val_loss:0.6495, val_acc:0.5556
# epoch:52, tr_loss:0.0592, tr_acc:1.0000,   val_loss:0.6699, val_acc:0.5556
# epoch:53, tr_loss:0.0925, tr_acc:0.9722,   val_loss:0.6744, val_acc:0.6667
# epoch:54, tr_loss:0.0601, tr_acc:1.0000,   val_loss:0.6770, val_acc:0.5556
# epoch:55, tr_loss:0.0620, tr_acc:0.9722,   val_loss:0.7173, val_acc:0.3333
# epoch:56, tr_loss:0.0874, tr_acc:1.0000,   val_loss:0.7247, val_acc:0.4444
# epoch:57, tr_loss:0.0608, tr_acc:1.0000,   val_loss:0.7921, val_acc:0.4444
# epoch:58, tr_loss:0.0696, tr_acc:1.0000,   val_loss:0.8740, val_acc:0.4444
# epoch:59, tr_loss:0.0431, tr_acc:1.0000,   val_loss:0.8290, val_acc:0.4444
# epoch:60, tr_loss:0.0824, tr_acc:0.9722,   val_loss:0.8163, val_acc:0.4444
# epoch:61, tr_loss:0.1021, tr_acc:0.9722,   val_loss:0.7703, val_acc:0.4444
# epoch:62, tr_loss:0.0713, tr_acc:0.9722,   val_loss:0.9308, val_acc:0.3333
# epoch:63, tr_loss:0.1707, tr_acc:0.9167,   val_loss:0.7617, val_acc:0.5556
# epoch:64, tr_loss:0.1528, tr_acc:0.8889,   val_loss:0.8061, val_acc:0.4444
# epoch:65, tr_loss:0.1253, tr_acc:0.9722,   val_loss:0.8818, val_acc:0.4444
# epoch:66, tr_loss:0.1086, tr_acc:0.9444,   val_loss:0.8561, val_acc:0.4444
# epoch:67, tr_loss:0.1582, tr_acc:0.9444,   val_loss:0.7756, val_acc:0.4444
# epoch:68, tr_loss:0.0987, tr_acc:0.9722,   val_loss:0.8028, val_acc:0.4444
# epoch:69, tr_loss:0.1302, tr_acc:0.9722,   val_loss:0.8725, val_acc:0.3333
# epoch:70, tr_loss:0.2362, tr_acc:0.9444,   val_loss:0.7620, val_acc:0.5556
# epoch:71, tr_loss:0.2479, tr_acc:0.8889,   val_loss:0.7620, val_acc:0.4444
# epoch:72, tr_loss:0.0815, tr_acc:0.9722,   val_loss:0.7620, val_acc:0.4444
# epoch:73, tr_loss:0.0884, tr_acc:0.9722,   val_loss:0.7996, val_acc:0.5556
# epoch:74, tr_loss:0.0597, tr_acc:1.0000,   val_loss:0.8574, val_acc:0.5556
# epoch:75, tr_loss:0.0609, tr_acc:1.0000,   val_loss:0.7731, val_acc:0.5556
# epoch:76, tr_loss:0.0842, tr_acc:1.0000,   val_loss:0.8061, val_acc:0.4444
# epoch:77, tr_loss:0.0969, tr_acc:0.9722,   val_loss:0.8327, val_acc:0.4444
# epoch:78, tr_loss:0.0733, tr_acc:1.0000,   val_loss:0.8207, val_acc:0.4444
# epoch:79, tr_loss:0.0770, tr_acc:1.0000,   val_loss:0.8490, val_acc:0.5556
# epoch:80, tr_loss:0.0507, tr_acc:1.0000,   val_loss:0.8713, val_acc:0.5556
# epoch:81, tr_loss:0.0354, tr_acc:1.0000,   val_loss:0.8954, val_acc:0.5556
# epoch:82, tr_loss:0.0552, tr_acc:0.9722,   val_loss:0.9155, val_acc:0.5556
# epoch:83, tr_loss:0.0657, tr_acc:0.9722,   val_loss:0.9388, val_acc:0.5556
# epoch:84, tr_loss:0.0494, tr_acc:1.0000,   val_loss:0.9632, val_acc:0.5556
# epoch:85, tr_loss:0.0842, tr_acc:0.9722,   val_loss:0.9615, val_acc:0.5556
# epoch:86, tr_loss:0.0255, tr_acc:1.0000,   val_loss:0.9389, val_acc:0.5556
# epoch:87, tr_loss:0.0791, tr_acc:0.9722,   val_loss:0.9481, val_acc:0.5556
# epoch:88, tr_loss:0.0253, tr_acc:1.0000,   val_loss:0.9804, val_acc:0.5556
# epoch:89, tr_loss:0.0251, tr_acc:1.0000,   val_loss:0.9880, val_acc:0.5556
# epoch:90, tr_loss:0.0493, tr_acc:1.0000,   val_loss:0.9919, val_acc:0.5556
# epoch:91, tr_loss:0.0533, tr_acc:1.0000,   val_loss:1.0012, val_acc:0.5556
# epoch:92, tr_loss:0.0463, tr_acc:1.0000,   val_loss:1.0041, val_acc:0.5556
# epoch:93, tr_loss:0.0311, tr_acc:1.0000,   val_loss:1.0183, val_acc:0.5556
# epoch:94, tr_loss:0.0225, tr_acc:1.0000,   val_loss:1.0357, val_acc:0.5556
# epoch:95, tr_loss:0.0685, tr_acc:0.9722,   val_loss:1.0647, val_acc:0.4444
# epoch:96, tr_loss:0.0252, tr_acc:1.0000,   val_loss:1.1470, val_acc:0.3333
# epoch:97, tr_loss:0.0507, tr_acc:0.9722,   val_loss:1.1850, val_acc:0.3333
# epoch:98, tr_loss:0.1250, tr_acc:0.9444,   val_loss:1.0825, val_acc:0.4444
# epoch:99, tr_loss:0.0278, tr_acc:1.0000,   val_loss:1.1238, val_acc:0.3333
# epoch:100, tr_loss:0.0433, tr_acc:1.0000,   val_loss:1.0777, val_acc:0.4444
# ----------finish training---------
# training_best_acc:1.0, val_best_acc:0.6666666666666666
# ----------start training----------
# epoch:1, tr_loss:0.5680, tr_acc:0.5278,   val_loss:0.3258, val_acc:0.7778
# epoch:2, tr_loss:0.5565, tr_acc:0.5278,   val_loss:0.3223, val_acc:0.7778
# epoch:3, tr_loss:0.5274, tr_acc:0.6111,   val_loss:0.3249, val_acc:0.6667
# epoch:4, tr_loss:0.5250, tr_acc:0.5833,   val_loss:0.3263, val_acc:0.6667
# epoch:5, tr_loss:0.5227, tr_acc:0.7222,   val_loss:0.3276, val_acc:0.6667
# epoch:6, tr_loss:0.5205, tr_acc:0.6667,   val_loss:0.3284, val_acc:0.6667
# epoch:7, tr_loss:0.5074, tr_acc:0.8056,   val_loss:0.3296, val_acc:0.6667
# epoch:8, tr_loss:0.5224, tr_acc:0.6389,   val_loss:0.3315, val_acc:0.6667
# epoch:9, tr_loss:0.5191, tr_acc:0.6389,   val_loss:0.3322, val_acc:0.6667
# epoch:10, tr_loss:0.5237, tr_acc:0.6389,   val_loss:0.3329, val_acc:0.5556
# epoch:11, tr_loss:0.5088, tr_acc:0.6944,   val_loss:0.3334, val_acc:0.5556
# epoch:12, tr_loss:0.4819, tr_acc:0.7778,   val_loss:0.3346, val_acc:0.5556
# epoch:13, tr_loss:0.4897, tr_acc:0.6944,   val_loss:0.3362, val_acc:0.5556
# epoch:14, tr_loss:0.4787, tr_acc:0.8333,   val_loss:0.3352, val_acc:0.5556
# epoch:15, tr_loss:0.4776, tr_acc:0.6944,   val_loss:0.3337, val_acc:0.5556
# epoch:16, tr_loss:0.4755, tr_acc:0.8056,   val_loss:0.3300, val_acc:0.5556
# epoch:17, tr_loss:0.4437, tr_acc:0.8333,   val_loss:0.3297, val_acc:0.5556
# epoch:18, tr_loss:0.4227, tr_acc:0.8889,   val_loss:0.3297, val_acc:0.5556
# epoch:19, tr_loss:0.4341, tr_acc:0.8889,   val_loss:0.3296, val_acc:0.6667
# epoch:20, tr_loss:0.4527, tr_acc:0.8056,   val_loss:0.3303, val_acc:0.5556
# epoch:21, tr_loss:0.4072, tr_acc:0.8333,   val_loss:0.3296, val_acc:0.5556
# epoch:22, tr_loss:0.3896, tr_acc:0.8611,   val_loss:0.3326, val_acc:0.5556
# epoch:23, tr_loss:0.4081, tr_acc:0.8333,   val_loss:0.3389, val_acc:0.5556
# epoch:24, tr_loss:0.3740, tr_acc:0.8611,   val_loss:0.3378, val_acc:0.5556
# epoch:25, tr_loss:0.4065, tr_acc:0.8611,   val_loss:0.3401, val_acc:0.5556
# epoch:26, tr_loss:0.3899, tr_acc:0.8333,   val_loss:0.3580, val_acc:0.5556
# epoch:27, tr_loss:0.3538, tr_acc:0.8889,   val_loss:0.3569, val_acc:0.5556
# epoch:28, tr_loss:0.3154, tr_acc:0.9167,   val_loss:0.3500, val_acc:0.5556
# epoch:29, tr_loss:0.3545, tr_acc:0.8889,   val_loss:0.3489, val_acc:0.5556
# epoch:30, tr_loss:0.3615, tr_acc:0.8889,   val_loss:0.3508, val_acc:0.5556
# epoch:31, tr_loss:0.3101, tr_acc:0.9444,   val_loss:0.3583, val_acc:0.5556
# epoch:32, tr_loss:0.2519, tr_acc:1.0000,   val_loss:0.3652, val_acc:0.5556
# epoch:33, tr_loss:0.3366, tr_acc:0.8889,   val_loss:0.3760, val_acc:0.5556
# epoch:34, tr_loss:0.2750, tr_acc:0.9167,   val_loss:0.3905, val_acc:0.5556
# epoch:35, tr_loss:0.2684, tr_acc:0.8889,   val_loss:0.3773, val_acc:0.5556
# epoch:36, tr_loss:0.2630, tr_acc:0.9722,   val_loss:0.3743, val_acc:0.5556
# epoch:37, tr_loss:0.2333, tr_acc:0.9444,   val_loss:0.3830, val_acc:0.6667
# epoch:38, tr_loss:0.1891, tr_acc:1.0000,   val_loss:0.3983, val_acc:0.6667
# epoch:39, tr_loss:0.3264, tr_acc:0.8611,   val_loss:0.4067, val_acc:0.5556
# epoch:40, tr_loss:0.2567, tr_acc:0.9444,   val_loss:0.3868, val_acc:0.5556
# epoch:41, tr_loss:0.2473, tr_acc:0.9722,   val_loss:0.4075, val_acc:0.5556
# epoch:42, tr_loss:0.2441, tr_acc:0.9444,   val_loss:0.4385, val_acc:0.5556
# epoch:43, tr_loss:0.2334, tr_acc:0.9167,   val_loss:0.4382, val_acc:0.5556
# epoch:44, tr_loss:0.2110, tr_acc:0.9722,   val_loss:0.4364, val_acc:0.5556
# epoch:45, tr_loss:0.2214, tr_acc:0.9167,   val_loss:0.4568, val_acc:0.5556
# epoch:46, tr_loss:0.1637, tr_acc:0.9722,   val_loss:0.4644, val_acc:0.5556
# epoch:47, tr_loss:0.1460, tr_acc:1.0000,   val_loss:0.4508, val_acc:0.5556
# epoch:48, tr_loss:0.1481, tr_acc:0.9722,   val_loss:0.4600, val_acc:0.6667
# epoch:49, tr_loss:0.1682, tr_acc:0.9444,   val_loss:0.4545, val_acc:0.6667
# epoch:50, tr_loss:0.1235, tr_acc:0.9722,   val_loss:0.4376, val_acc:0.6667
# epoch:51, tr_loss:0.1470, tr_acc:0.9444,   val_loss:0.4613, val_acc:0.6667
# epoch:52, tr_loss:0.1369, tr_acc:1.0000,   val_loss:0.4785, val_acc:0.6667
# epoch:53, tr_loss:0.1633, tr_acc:0.9722,   val_loss:0.4775, val_acc:0.5556
# epoch:54, tr_loss:0.1364, tr_acc:0.9722,   val_loss:0.4977, val_acc:0.5556
# epoch:55, tr_loss:0.1129, tr_acc:0.9722,   val_loss:0.5091, val_acc:0.5556
# epoch:56, tr_loss:0.1018, tr_acc:1.0000,   val_loss:0.5190, val_acc:0.5556
# epoch:57, tr_loss:0.0870, tr_acc:1.0000,   val_loss:0.5308, val_acc:0.5556
# epoch:58, tr_loss:0.1038, tr_acc:1.0000,   val_loss:0.5599, val_acc:0.5556
# epoch:59, tr_loss:0.0622, tr_acc:1.0000,   val_loss:0.5766, val_acc:0.5556
# epoch:60, tr_loss:0.0787, tr_acc:1.0000,   val_loss:0.5856, val_acc:0.5556
# epoch:61, tr_loss:0.0851, tr_acc:1.0000,   val_loss:0.6076, val_acc:0.5556
# epoch:62, tr_loss:0.0655, tr_acc:0.9722,   val_loss:0.6283, val_acc:0.5556
# epoch:63, tr_loss:0.0615, tr_acc:1.0000,   val_loss:0.6345, val_acc:0.5556
# epoch:64, tr_loss:0.0610, tr_acc:1.0000,   val_loss:0.6622, val_acc:0.5556
# epoch:65, tr_loss:0.1036, tr_acc:0.9722,   val_loss:0.6770, val_acc:0.5556
# epoch:66, tr_loss:0.0511, tr_acc:1.0000,   val_loss:0.6886, val_acc:0.5556
# epoch:67, tr_loss:0.0450, tr_acc:1.0000,   val_loss:0.7001, val_acc:0.5556
# epoch:68, tr_loss:0.0536, tr_acc:1.0000,   val_loss:0.7055, val_acc:0.5556
# epoch:69, tr_loss:0.0604, tr_acc:1.0000,   val_loss:0.7087, val_acc:0.5556
# epoch:70, tr_loss:0.0467, tr_acc:1.0000,   val_loss:0.7019, val_acc:0.5556
# epoch:71, tr_loss:0.0600, tr_acc:1.0000,   val_loss:0.7032, val_acc:0.5556
# epoch:72, tr_loss:0.0446, tr_acc:1.0000,   val_loss:0.7078, val_acc:0.5556
# epoch:73, tr_loss:0.0534, tr_acc:1.0000,   val_loss:0.6961, val_acc:0.5556
# epoch:74, tr_loss:0.0717, tr_acc:1.0000,   val_loss:0.6958, val_acc:0.5556
# epoch:75, tr_loss:0.0445, tr_acc:1.0000,   val_loss:0.7252, val_acc:0.5556
# epoch:76, tr_loss:0.1051, tr_acc:0.9722,   val_loss:0.7125, val_acc:0.5556
# epoch:77, tr_loss:0.0769, tr_acc:0.9722,   val_loss:0.6545, val_acc:0.5556
# epoch:78, tr_loss:0.1129, tr_acc:0.9167,   val_loss:0.6825, val_acc:0.5556
# epoch:79, tr_loss:0.1416, tr_acc:0.9167,   val_loss:0.7181, val_acc:0.5556
# epoch:80, tr_loss:0.1661, tr_acc:0.9444,   val_loss:0.6960, val_acc:0.5556
# epoch:81, tr_loss:0.2154, tr_acc:0.9167,   val_loss:0.6908, val_acc:0.5556
# epoch:82, tr_loss:0.1071, tr_acc:0.9722,   val_loss:0.6892, val_acc:0.5556
# epoch:83, tr_loss:0.0841, tr_acc:1.0000,   val_loss:0.6776, val_acc:0.5556
# epoch:84, tr_loss:0.0891, tr_acc:0.9722,   val_loss:0.6561, val_acc:0.5556
# epoch:85, tr_loss:0.1154, tr_acc:0.9444,   val_loss:0.6566, val_acc:0.5556
# epoch:86, tr_loss:0.0738, tr_acc:1.0000,   val_loss:0.6897, val_acc:0.5556
# epoch:87, tr_loss:0.0650, tr_acc:1.0000,   val_loss:0.7033, val_acc:0.5556
# epoch:88, tr_loss:0.0806, tr_acc:0.9722,   val_loss:0.7053, val_acc:0.5556
# epoch:89, tr_loss:0.0465, tr_acc:1.0000,   val_loss:0.6824, val_acc:0.6667
# epoch:90, tr_loss:0.0565, tr_acc:1.0000,   val_loss:0.7038, val_acc:0.6667
# epoch:91, tr_loss:0.0573, tr_acc:1.0000,   val_loss:0.7844, val_acc:0.5556
# epoch:92, tr_loss:0.0562, tr_acc:0.9722,   val_loss:0.8006, val_acc:0.5556
# epoch:93, tr_loss:0.0340, tr_acc:1.0000,   val_loss:0.8113, val_acc:0.5556
# epoch:94, tr_loss:0.0499, tr_acc:1.0000,   val_loss:0.8321, val_acc:0.5556
# epoch:95, tr_loss:0.0339, tr_acc:1.0000,   val_loss:0.8621, val_acc:0.5556
# epoch:96, tr_loss:0.0259, tr_acc:1.0000,   val_loss:0.8961, val_acc:0.5556
# epoch:97, tr_loss:0.0509, tr_acc:1.0000,   val_loss:0.9102, val_acc:0.5556
# epoch:98, tr_loss:0.0382, tr_acc:1.0000,   val_loss:0.9139, val_acc:0.5556
# epoch:99, tr_loss:0.0358, tr_acc:1.0000,   val_loss:0.8897, val_acc:0.5556
# epoch:100, tr_loss:0.0318, tr_acc:1.0000,   val_loss:0.8718, val_acc:0.5556
# ----------finish training---------
# training_best_acc:1.0, val_best_acc:0.7777777777777778
# ----------start training----------
# epoch:1, tr_loss:0.5666, tr_acc:0.4722,   val_loss:0.3573, val_acc:0.4444
# epoch:2, tr_loss:0.5607, tr_acc:0.5000,   val_loss:0.3531, val_acc:0.4444
# epoch:3, tr_loss:0.5585, tr_acc:0.5000,   val_loss:0.3526, val_acc:0.4444
# epoch:4, tr_loss:0.5334, tr_acc:0.6111,   val_loss:0.3523, val_acc:0.4444
# epoch:5, tr_loss:0.5431, tr_acc:0.5833,   val_loss:0.3536, val_acc:0.4444
# epoch:6, tr_loss:0.5438, tr_acc:0.5833,   val_loss:0.3538, val_acc:0.4444
# epoch:7, tr_loss:0.5238, tr_acc:0.6389,   val_loss:0.3539, val_acc:0.4444
# epoch:8, tr_loss:0.5375, tr_acc:0.5833,   val_loss:0.3529, val_acc:0.4444
# epoch:9, tr_loss:0.5288, tr_acc:0.6111,   val_loss:0.3527, val_acc:0.4444
# epoch:10, tr_loss:0.5260, tr_acc:0.6389,   val_loss:0.3530, val_acc:0.4444
# epoch:11, tr_loss:0.5080, tr_acc:0.7500,   val_loss:0.3525, val_acc:0.4444
# epoch:12, tr_loss:0.4973, tr_acc:0.7222,   val_loss:0.3513, val_acc:0.4444
# epoch:13, tr_loss:0.5178, tr_acc:0.6944,   val_loss:0.3494, val_acc:0.5556
# epoch:14, tr_loss:0.5250, tr_acc:0.6944,   val_loss:0.3500, val_acc:0.5556
# epoch:15, tr_loss:0.4810, tr_acc:0.7222,   val_loss:0.3498, val_acc:0.6667
# epoch:16, tr_loss:0.5005, tr_acc:0.7222,   val_loss:0.3499, val_acc:0.5556
# epoch:17, tr_loss:0.4609, tr_acc:0.8889,   val_loss:0.3489, val_acc:0.6667
# epoch:18, tr_loss:0.4576, tr_acc:0.7778,   val_loss:0.3454, val_acc:0.6667
# epoch:19, tr_loss:0.4329, tr_acc:0.9444,

# %%
accs = np.array(all_accs_list)
accs = accs.reshape(-1)
sns.set_style("ticks")
plt.title('histgram of validation accracy')
plt.xlabel('accuracy')
sns.distplot(accs, kde=False);
plt.show()

# %%
accs = np.array(all_mean_list)
accs = accs.reshape(-1)
sns.set_style("ticks")
plt.title('histgram of cross validation accracy')
plt.xlabel('accuracy')
sns.distplot(accs, kde=False);
plt.show()

# %%
x
